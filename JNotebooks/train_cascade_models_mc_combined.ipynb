# %%
# Importing standard libraries
import numpy as np
import os
import glob
import sys
import importlib
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import  Adam
from tensorflow.keras.models import load_model
import pickle
import tensorflow as tf

# Include path to my modules
MY_UTILS_PATH = "../Modules/"
if not MY_UTILS_PATH in sys.path:
    sys.path.append(MY_UTILS_PATH)

# Import my modules
import cs_models_mc_combined as fsnet
importlib.reload(fsnet)
import cs_models_mc_combined as fsnet
from data_generator_mc_combined import DataGenerator

physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# Input parameters
H = 218
W = 170
channels = 12
batch_size = 8
epochs = 100
lr = 1e-4
patience = 10
sampling_mask_path = "../Data/poisson_sampling/R10_218x170.npy"
model_path =  "../Models/model_wwnet_ikik_mcc_r5.h5"
weights_path = "../Models/weights_wwnet_ikik_mcc_r5.h5"
model_string = "ikik"
train_path = "../../data/train_val_12_channel/Train/"
val_path = "../../data/train_val_12_channel/Val/"
cascade = "unet"
nslices = 256
crop = (15, 15)
verbose = True

# %%
train = glob.glob(train_path + "*.h5")
val = glob.glob(val_path + "*.h5")

# undersampling patterns - centered k-space - 100 pre computed patterns
var_sampling_mask = np.load(sampling_mask_path)


if verbose:
    print(cascade)
    print("Domains: ", model_string)
    print("Model name: ", model_path)
    print("Weights path: ", weights_path)
    print("Sampling:", 1.0*var_sampling_mask.sum() / (var_sampling_mask.size*0.85)) # 85 % sampling Kz direction
    print("Train path: ", train_path)
    print("Validation path: ", val_path)


# Replicate sampling mask across number of channels
var_sampling_mask = np.repeat(var_sampling_mask[:, :, :, np.newaxis], 24, axis = -1) 

# train_generator = DataGenerator(train, dim = (H, W), under_masks = var_sampling_mask,  crop = crop,\
#                             batch_size = batch_size, n_channels = channels, nslices = nslices, shuffle=True)

# val_generator = DataGenerator(val, dim = (H, W), under_masks = var_sampling_mask,  crop = crop,\
#                             batch_size = batch_size, n_channels = channels, nslices= nslices, shuffle=False)



# Callbacks
earlyStopping = EarlyStopping(monitor='val_loss',
                                           patience=patience, 
                                           verbose=0, mode='min')

checkpoint = ModelCheckpoint(weights_path, mode = 'min', \
                             monitor='val_loss',verbose=0,\
                             save_best_only=True, save_weights_only = True)

checkpoint2 = ModelCheckpoint(model_path, monitor='val_loss', verbose=0, save_best_only=False,\
                save_weights_only=False, mode='min')

Hpad = (8 - (H%8)) // 2
Wpad = (8 - (W%8)) // 2
if os.path.isfile(model_path):
    model = load_model(model_path)
elif  cascade == 'unet':
    model = fsnet.deep_cascade_unet(depth_str = model_string, H = H, W = W, Hpad = Hpad, Wpad = Wpad, channels = channels) 
elif cascade == 'flat':
    model = fsnet.deep_cascade_flat_unrolled(depth_str = model_string, H = H,W = W,depth = 6, kshape = (3,3), nf = 64,channels = channels)
else:
   pass

if not os.path.isfile(model_path):
    opt = Adam(learning_rate = lr)
    model.compile(loss = 'mse',optimizer=opt)

if verbose:
    print(model.summary())

# hist = model.fit(train_generator, epochs = epochs, steps_per_epoch = ( (nslices - crop[0] - crop[1])*len(train) ) // batch_size, \
#              validation_data = val_generator, validation_steps = ( (nslices - crop[0] - crop[1])*len(val) ) // batch_size, \
#                    callbacks = [ checkpoint2, checkpoint, earlyStopping ], verbose = 1)

# # Save model history
# with open(model_path[:-2] + "history", 'wb') as file_pi:
#     pickle.dump(hist.history, file_pi)
# Out:
# unet
# Domains:  ikik
# Model name:  ../Models/model_wwnet_ikik_mcc_r5.h5
# Weights path:  ../Models/weights_wwnet_ikik_mcc_r5.h5
# Sampling: 0.10023269102568172
# Train path:  ../../data/train_val_12_channel/Train/
# Validation path:  ../../data/train_val_12_channel/Val/
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_37 (InputLayer)           [(None, 218, 170, 2) 0
# __________________________________________________________________________________________________
# lambda_186 (Lambda)             (None, 218, 170, 2)  0           input_37[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 224, 176, 2)  0           lambda_186[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 224, 176, 48) 912         zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_265 (Conv2D)             (None, 224, 176, 48) 20784       conv2d_264[0][0]
# __________________________________________________________________________________________________
# conv2d_266 (Conv2D)             (None, 224, 176, 48) 20784       conv2d_265[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, 112, 88, 48)  0           conv2d_266[0][0]
# __________________________________________________________________________________________________
# conv2d_267 (Conv2D)             (None, 112, 88, 64)  27712       max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_268 (Conv2D)             (None, 112, 88, 64)  36928       conv2d_267[0][0]
# __________________________________________________________________________________________________
# conv2d_269 (Conv2D)             (None, 112, 88, 64)  36928       conv2d_268[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_37 (MaxPooling2D) (None, 56, 44, 64)   0           conv2d_269[0][0]
# __________________________________________________________________________________________________
# conv2d_270 (Conv2D)             (None, 56, 44, 128)  73856       max_pooling2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_271 (Conv2D)             (None, 56, 44, 128)  147584      conv2d_270[0][0]
# __________________________________________________________________________________________________
# conv2d_272 (Conv2D)             (None, 56, 44, 128)  147584      conv2d_271[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_38 (MaxPooling2D) (None, 28, 22, 128)  0           conv2d_272[0][0]
# __________________________________________________________________________________________________
# conv2d_273 (Conv2D)             (None, 28, 22, 256)  295168      max_pooling2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_274 (Conv2D)             (None, 28, 22, 256)  590080      conv2d_273[0][0]
# __________________________________________________________________________________________________
# conv2d_275 (Conv2D)             (None, 28, 22, 256)  590080      conv2d_274[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_36 (UpSampling2D) (None, 56, 44, 256)  0           conv2d_275[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 56, 44, 384)  0           up_sampling2d_36[0][0]
#                                                                  conv2d_272[0][0]
# __________________________________________________________________________________________________
# conv2d_276 (Conv2D)             (None, 56, 44, 128)  442496      concatenate_36[0][0]
# __________________________________________________________________________________________________
# conv2d_277 (Conv2D)             (None, 56, 44, 128)  147584      conv2d_276[0][0]
# __________________________________________________________________________________________________
# conv2d_278 (Conv2D)             (None, 56, 44, 128)  147584      conv2d_277[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_37 (UpSampling2D) (None, 112, 88, 128) 0           conv2d_278[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 112, 88, 192) 0           up_sampling2d_37[0][0]
#                                                                  conv2d_269[0][0]
# __________________________________________________________________________________________________
# conv2d_279 (Conv2D)             (None, 112, 88, 64)  110656      concatenate_37[0][0]
# __________________________________________________________________________________________________
# conv2d_280 (Conv2D)             (None, 112, 88, 64)  36928       conv2d_279[0][0]
# __________________________________________________________________________________________________
# conv2d_281 (Conv2D)             (None, 112, 88, 64)  36928       conv2d_280[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_38 (UpSampling2D) (None, 224, 176, 64) 0           conv2d_281[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 224, 176, 112 0           up_sampling2d_38[0][0]
#                                                                  conv2d_266[0][0]
# __________________________________________________________________________________________________
# conv2d_282 (Conv2D)             (None, 224, 176, 48) 48432       concatenate_38[0][0]
# __________________________________________________________________________________________________
# conv2d_283 (Conv2D)             (None, 224, 176, 48) 20784       conv2d_282[0][0]
# __________________________________________________________________________________________________
# conv2d_284 (Conv2D)             (None, 224, 176, 48) 20784       conv2d_283[0][0]
# __________________________________________________________________________________________________
# conv2d_285 (Conv2D)             (None, 224, 176, 2)  98          conv2d_284[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 224, 176, 2)  0           conv2d_285[0][0]
#                                                                  zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# cropping2d_12 (Cropping2D)      (None, 218, 170, 2)  0           add_13[0][0]
# __________________________________________________________________________________________________
# lambda_187 (Lambda)             (None, 218, 170, 2)  0           cropping2d_12[0][0]
# __________________________________________________________________________________________________
# lambda_188 (Lambda)             (None, 218, 170, 2)  0           lambda_187[0][0]
# __________________________________________________________________________________________________
# lambda_189 (Lambda)             (None, 218, 170)     0           lambda_188[0][0]
# __________________________________________________________________________________________________
# lambda_190 (Lambda)             (None, 218, 170)     0           lambda_188[0][0]
# __________________________________________________________________________________________________
# lambda_215 (Lambda)             (None, 218, 170, 2)  0           input_37[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_62 (TensorF [(None, 218, 170)]   0           lambda_189[0][0]
#                                                                  lambda_190[0][0]
# __________________________________________________________________________________________________
# input_39 (InputLayer)           [(None, 218, 170, 12 0
# __________________________________________________________________________________________________
# lambda_216 (Lambda)             (None, 218, 170)     0           lambda_215[0][0]
# __________________________________________________________________________________________________
# lambda_217 (Lambda)             (None, 218, 170)     0           lambda_215[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_206 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Complex_62[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape_5 (TensorFlow [(4,)]               0           input_39[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_75 (TensorF [(None, 218, 170)]   0           lambda_216[0][0]
#                                                                  lambda_217[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_BroadcastTo_14 (Ten [(None, 218, 170, 12 0           tf_op_layer_ExpandDims_206[0][0]
#                                                                  tf_op_layer_Shape_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_255 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Complex_75[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape_6 (TensorFlow [(4,)]               0           input_39[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_4 (TensorFlowOp [(None, 218, 170, 12 0           tf_op_layer_BroadcastTo_14[0][0]
#                                                                  input_39[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_BroadcastTo_15 (Ten [(None, 218, 170, 12 0           tf_op_layer_ExpandDims_255[0][0]
#                                                                  tf_op_layer_Shape_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_52 (TensorFlow [(None, 218, 170, 12 0           tf_op_layer_Mul_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_52 (TensorFlow [(None, 218, 170, 12 0           tf_op_layer_Mul_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_5 (TensorFlowOp [(None, 218, 170, 12 0           tf_op_layer_BroadcastTo_15[0][0]
#                                                                  input_39[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_96 (T [(None, 218, 170)]   0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_97 (T [(None, 218, 170)]   0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_65 (TensorFlow [(None, 218, 170, 12 0           tf_op_layer_Mul_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_65 (TensorFlow [(None, 218, 170, 12 0           tf_op_layer_Mul_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_207 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_96[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_208 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_97[0][0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_98 (T [(None, 218, 170)]   0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_99 (T [(None, 218, 170)]   0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_120 ( [(None, 218, 170)]   0           tf_op_layer_Real_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_121 ( [(None, 218, 170)]   0           tf_op_layer_Imag_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_108 (TensorF [(None, 218, 170, 2) 0           tf_op_layer_ExpandDims_207[0][0]
#                                                                  tf_op_layer_ExpandDims_208[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_209 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_98[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_210 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_99[0][0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_100 ( [(None, 218, 170)]   0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_101 ( [(None, 218, 170)]   0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_256 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_120[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_257 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_121[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_122 ( [(None, 218, 170)]   0           tf_op_layer_Real_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_123 ( [(None, 218, 170)]   0           tf_op_layer_Imag_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_109 (TensorF [(None, 218, 170, 4) 0           tf_op_layer_concat_108[0][0]
#                                                                  tf_op_layer_ExpandDims_209[0][0]
#                                                                  tf_op_layer_ExpandDims_210[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_211 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_100[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_212 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_101[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_102 ( [(None, 218, 170)]   0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_103 ( [(None, 218, 170)]   0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_132 (TensorF [(None, 218, 170, 2) 0           tf_op_layer_ExpandDims_256[0][0]
#                                                                  tf_op_layer_ExpandDims_257[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_258 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_122[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_259 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_123[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_124 ( [(None, 218, 170)]   0           tf_op_layer_Real_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_125 ( [(None, 218, 170)]   0           tf_op_layer_Imag_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_110 (TensorF [(None, 218, 170, 6) 0           tf_op_layer_concat_109[0][0]
#                                                                  tf_op_layer_ExpandDims_211[0][0]
#                                                                  tf_op_layer_ExpandDims_212[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_213 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_102[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_214 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_103[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_104 ( [(None, 218, 170)]   0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_105 ( [(None, 218, 170)]   0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_133 (TensorF [(None, 218, 170, 4) 0           tf_op_layer_concat_132[0][0]
#                                                                  tf_op_layer_ExpandDims_258[0][0]
#                                                                  tf_op_layer_ExpandDims_259[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_260 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_124[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_261 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_125[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_126 ( [(None, 218, 170)]   0           tf_op_layer_Real_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_127 ( [(None, 218, 170)]   0           tf_op_layer_Imag_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_111 (TensorF [(None, 218, 170, 8) 0           tf_op_layer_concat_110[0][0]
#                                                                  tf_op_layer_ExpandDims_213[0][0]
#                                                                  tf_op_layer_ExpandDims_214[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_215 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_104[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_216 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_105[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_106 ( [(None, 218, 170)]   0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_107 ( [(None, 218, 170)]   0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_134 (TensorF [(None, 218, 170, 6) 0           tf_op_layer_concat_133[0][0]
#                                                                  tf_op_layer_ExpandDims_260[0][0]
#                                                                  tf_op_layer_ExpandDims_261[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_262 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_126[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_263 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_127[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_128 ( [(None, 218, 170)]   0           tf_op_layer_Real_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_129 ( [(None, 218, 170)]   0           tf_op_layer_Imag_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_112 (TensorF [(None, 218, 170, 10 0           tf_op_layer_concat_111[0][0]
#                                                                  tf_op_layer_ExpandDims_215[0][0]
#                                                                  tf_op_layer_ExpandDims_216[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_217 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_106[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_218 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_107[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_108 ( [(None, 218, 170)]   0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_109 ( [(None, 218, 170)]   0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_135 (TensorF [(None, 218, 170, 8) 0           tf_op_layer_concat_134[0][0]
#                                                                  tf_op_layer_ExpandDims_262[0][0]
#                                                                  tf_op_layer_ExpandDims_263[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_264 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_128[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_265 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_129[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_130 ( [(None, 218, 170)]   0           tf_op_layer_Real_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_131 ( [(None, 218, 170)]   0           tf_op_layer_Imag_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_113 (TensorF [(None, 218, 170, 12 0           tf_op_layer_concat_112[0][0]
#                                                                  tf_op_layer_ExpandDims_217[0][0]
#                                                                  tf_op_layer_ExpandDims_218[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_219 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_108[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_220 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_109[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_110 ( [(None, 218, 170)]   0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_111 ( [(None, 218, 170)]   0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_136 (TensorF [(None, 218, 170, 10 0           tf_op_layer_concat_135[0][0]
#                                                                  tf_op_layer_ExpandDims_264[0][0]
#                                                                  tf_op_layer_ExpandDims_265[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_266 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_130[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_267 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_131[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_132 ( [(None, 218, 170)]   0           tf_op_layer_Real_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_133 ( [(None, 218, 170)]   0           tf_op_layer_Imag_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_114 (TensorF [(None, 218, 170, 14 0           tf_op_layer_concat_113[0][0]
#                                                                  tf_op_layer_ExpandDims_219[0][0]
#                                                                  tf_op_layer_ExpandDims_220[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_221 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_110[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_222 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_111[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_112 ( [(None, 218, 170)]   0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_113 ( [(None, 218, 170)]   0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_137 (TensorF [(None, 218, 170, 12 0           tf_op_layer_concat_136[0][0]
#                                                                  tf_op_layer_ExpandDims_266[0][0]
#                                                                  tf_op_layer_ExpandDims_267[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_268 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_132[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_269 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_133[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_134 ( [(None, 218, 170)]   0           tf_op_layer_Real_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_135 ( [(None, 218, 170)]   0           tf_op_layer_Imag_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_115 (TensorF [(None, 218, 170, 16 0           tf_op_layer_concat_114[0][0]
#                                                                  tf_op_layer_ExpandDims_221[0][0]
#                                                                  tf_op_layer_ExpandDims_222[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_223 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_112[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_224 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_113[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_114 ( [(None, 218, 170)]   0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_115 ( [(None, 218, 170)]   0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_138 (TensorF [(None, 218, 170, 14 0           tf_op_layer_concat_137[0][0]
#                                                                  tf_op_layer_ExpandDims_268[0][0]
#                                                                  tf_op_layer_ExpandDims_269[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_270 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_134[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_271 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_135[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_136 ( [(None, 218, 170)]   0           tf_op_layer_Real_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_137 ( [(None, 218, 170)]   0           tf_op_layer_Imag_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_116 (TensorF [(None, 218, 170, 18 0           tf_op_layer_concat_115[0][0]
#                                                                  tf_op_layer_ExpandDims_223[0][0]
#                                                                  tf_op_layer_ExpandDims_224[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_225 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_114[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_226 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_115[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_116 ( [(None, 218, 170)]   0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_117 ( [(None, 218, 170)]   0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_139 (TensorF [(None, 218, 170, 16 0           tf_op_layer_concat_138[0][0]
#                                                                  tf_op_layer_ExpandDims_270[0][0]
#                                                                  tf_op_layer_ExpandDims_271[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_272 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_136[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_273 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_137[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_138 ( [(None, 218, 170)]   0           tf_op_layer_Real_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_139 ( [(None, 218, 170)]   0           tf_op_layer_Imag_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_117 (TensorF [(None, 218, 170, 20 0           tf_op_layer_concat_116[0][0]
#                                                                  tf_op_layer_ExpandDims_225[0][0]
#                                                                  tf_op_layer_ExpandDims_226[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_227 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_116[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_228 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_117[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_118 ( [(None, 218, 170)]   0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_119 ( [(None, 218, 170)]   0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_140 (TensorF [(None, 218, 170, 18 0           tf_op_layer_concat_139[0][0]
#                                                                  tf_op_layer_ExpandDims_272[0][0]
#                                                                  tf_op_layer_ExpandDims_273[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_274 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_138[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_275 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_139[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_140 ( [(None, 218, 170)]   0           tf_op_layer_Real_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_141 ( [(None, 218, 170)]   0           tf_op_layer_Imag_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_118 (TensorF [(None, 218, 170, 22 0           tf_op_layer_concat_117[0][0]
#                                                                  tf_op_layer_ExpandDims_227[0][0]
#                                                                  tf_op_layer_ExpandDims_228[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_229 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_118[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_230 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_119[0][
# __________________________________________________________________________________________________
# tf_op_layer_concat_141 (TensorF [(None, 218, 170, 20 0           tf_op_layer_concat_140[0][0]
#                                                                  tf_op_layer_ExpandDims_274[0][0]
#                                                                  tf_op_layer_ExpandDims_275[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_276 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_140[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_277 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_141[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_142 ( [(None, 218, 170)]   0           tf_op_layer_Real_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_143 ( [(None, 218, 170)]   0           tf_op_layer_Imag_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_119 (TensorF [(None, 218, 170, 24 0           tf_op_layer_concat_118[0][0]
#                                                                  tf_op_layer_ExpandDims_229[0][0]
#                                                                  tf_op_layer_ExpandDims_230[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_142 (TensorF [(None, 218, 170, 22 0           tf_op_layer_concat_141[0][0]
#                                                                  tf_op_layer_ExpandDims_276[0][0]
#                                                                  tf_op_layer_ExpandDims_277[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_278 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_142[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_279 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_143[0][
# __________________________________________________________________________________________________
# lambda_191 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_119[0][0]
# __________________________________________________________________________________________________
# lambda_192 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_119[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_143 (TensorF [(None, 218, 170, 24 0           tf_op_layer_concat_142[0][0]
#                                                                  tf_op_layer_ExpandDims_278[0][0]
#                                                                  tf_op_layer_ExpandDims_279[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_63 (TensorF [(None, 218, 170)]   0           lambda_191[0][0]
#                                                                  lambda_192[0][0]
# __________________________________________________________________________________________________
# lambda_193 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_119[0][0]
# __________________________________________________________________________________________________
# lambda_194 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_119[0][0]
# __________________________________________________________________________________________________
# lambda_218 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_143[0][0]
# __________________________________________________________________________________________________
# lambda_219 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_143[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_48 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_63[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_64 (TensorF [(None, 218, 170)]   0           lambda_193[0][0]
#                                                                  lambda_194[0][0]
# __________________________________________________________________________________________________
# lambda_195 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_119[0][0]
# __________________________________________________________________________________________________
# lambda_196 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_119[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_76 (TensorF [(None, 218, 170)]   0           lambda_218[0][0]
#                                                                  lambda_219[0][0]
# __________________________________________________________________________________________________
# lambda_220 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_143[0][0]
# __________________________________________________________________________________________________
# lambda_221 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_143[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_53 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_48[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_53 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_48[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_49 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_64[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_65 (TensorF [(None, 218, 170)]   0           lambda_195[0][0]
#                                                                  lambda_196[0][0]
# __________________________________________________________________________________________________
# lambda_197 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_119[0][0]
# __________________________________________________________________________________________________
# lambda_198 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_119[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_60 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_76[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_77 (TensorF [(None, 218, 170)]   0           lambda_220[0][0]
#                                                                  lambda_221[0][0]
# __________________________________________________________________________________________________
# lambda_222 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_143[0][0]
# __________________________________________________________________________________________________
# lambda_223 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_143[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_231 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_53[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_232 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_53[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_54 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_49[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_54 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_49[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_50 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_66 (TensorF [(None, 218, 170)]   0           lambda_197[0][0]
#                                                                  lambda_198[0][0]
# __________________________________________________________________________________________________
# lambda_199 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_119[0][0]
# ...
# tf_op_layer_ExpandDims_670 (Ten [(None, 218, 170, 1) 0           lambda_478[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_671 (Ten [(None, 218, 170, 1) 0           lambda_479[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_672 (Ten [(None, 218, 170, 1) 0           lambda_480[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_673 (Ten [(None, 218, 170, 1) 0           lambda_481[0][0]
# __________________________________________________________________________________________________
# lambda_482 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# lambda_483 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_336 (TensorF [(None, 218, 170, 2) 0           tf_op_layer_ExpandDims_670[0][0]
#                                                                  tf_op_layer_ExpandDims_671[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_337 (TensorF [(None, 218, 170, 2) 0           tf_op_layer_ExpandDims_672[0][0]
#                                                                  tf_op_layer_ExpandDims_673[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_674 (Ten [(None, 218, 170, 1) 0           lambda_482[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_675 (Ten [(None, 218, 170, 1) 0           lambda_483[0][0]
# __________________________________________________________________________________________________
# lambda_484 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# lambda_485 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Add_57 (TensorFlowO [(None, 218, 170, 2) 0           tf_op_layer_concat_336[0][0]
#                                                                  tf_op_layer_concat_337[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_338 (TensorF [(None, 218, 170, 2) 0           tf_op_layer_ExpandDims_674[0][0]
#                                                                  tf_op_layer_ExpandDims_675[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_676 (Ten [(None, 218, 170, 1) 0           lambda_484[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_677 (Ten [(None, 218, 170, 1) 0           lambda_485[0][0]
# __________________________________________________________________________________________________
# lambda_486 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# lambda_487 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Add_58 (TensorFlowO [(None, 218, 170, 2) 0           tf_op_layer_Add_57[0][0]
#                                                                  tf_op_layer_concat_338[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_339 (TensorF [(None, 218, 170, 2) 0           tf_op_layer_ExpandDims_676[0][0]
#                                                                  tf_op_layer_ExpandDims_677[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_678 (Ten [(None, 218, 170, 1) 0           lambda_486[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_679 (Ten [(None, 218, 170, 1) 0           lambda_487[0][0]
# __________________________________________________________________________________________________
# lambda_488 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# lambda_489 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Add_59 (TensorFlowO [(None, 218, 170, 2) 0           tf_op_layer_Add_58[0][0]
#                                                                  tf_op_layer_concat_339[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_340 (TensorF [(None, 218, 170, 2) 0           tf_op_layer_ExpandDims_678[0][0]
#                                                                  tf_op_layer_ExpandDims_679[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_680 (Ten [(None, 218, 170, 1) 0           lambda_488[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_681 (Ten [(None, 218, 170, 1) 0           lambda_489[0][0]
# __________________________________________________________________________________________________
# lambda_490 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# lambda_491 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Add_60 (TensorFlowO [(None, 218, 170, 2) 0           tf_op_layer_Add_59[0][0]
#                                                                  tf_op_layer_concat_340[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_341 (TensorF [(None, 218, 170, 2) 0           tf_op_layer_ExpandDims_680[0][0]
#                                                                  tf_op_layer_ExpandDims_681[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_682 (Ten [(None, 218, 170, 1) 0           lambda_490[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_683 (Ten [(None, 218, 170, 1) 0           lambda_491[0][0]
# __________________________________________________________________________________________________
# lambda_492 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# lambda_493 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Add_61 (TensorFlowO [(None, 218, 170, 2) 0           tf_op_layer_Add_60[0][0]
#                                                                  tf_op_layer_concat_341[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_342 (TensorF [(None, 218, 170, 2) 0           tf_op_layer_ExpandDims_682[0][0]
#                                                                  tf_op_layer_ExpandDims_683[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_684 (Ten [(None, 218, 170, 1) 0           lambda_492[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_685 (Ten [(None, 218, 170, 1) 0           lambda_493[0][0]
# __________________________________________________________________________________________________
# lambda_494 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# lambda_495 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Add_62 (TensorFlowO [(None, 218, 170, 2) 0           tf_op_layer_Add_61[0][0]
#                                                                  tf_op_layer_concat_342[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_343 (TensorF [(None, 218, 170, 2) 0           tf_op_layer_ExpandDims_684[0][0]
#                                                                  tf_op_layer_ExpandDims_685[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_686 (Ten [(None, 218, 170, 1) 0           lambda_494[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_687 (Ten [(None, 218, 170, 1) 0           lambda_495[0][0]
# __________________________________________________________________________________________________
# lambda_496 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# lambda_497 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Add_63 (TensorFlowO [(None, 218, 170, 2) 0           tf_op_layer_Add_62[0][0]
#                                                                  tf_op_layer_concat_343[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_344 (TensorF [(None, 218, 170, 2) 0           tf_op_layer_ExpandDims_686[0][0]
#                                                                  tf_op_layer_ExpandDims_687[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_688 (Ten [(None, 218, 170, 1) 0           lambda_496[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_689 (Ten [(None, 218, 170, 1) 0           lambda_497[0][0]
# __________________________________________________________________________________________________
# lambda_498 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# lambda_499 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Add_64 (TensorFlowO [(None, 218, 170, 2) 0           tf_op_layer_Add_63[0][0]
#                                                                  tf_op_layer_concat_344[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_345 (TensorF [(None, 218, 170, 2) 0           tf_op_layer_ExpandDims_688[0][0]
#                                                                  tf_op_layer_ExpandDims_689[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_690 (Ten [(None, 218, 170, 1) 0           lambda_498[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_691 (Ten [(None, 218, 170, 1) 0           lambda_499[0][0]
# __________________________________________________________________________________________________
# lambda_500 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# lambda_501 (Lambda)             (None, 218, 170)     0           add_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Add_65 (TensorFlowO [(None, 218, 170, 2) 0           tf_op_layer_Add_64[0][0]
#                                                                  tf_op_layer_concat_345[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_346 (TensorF [(None, 218, 170, 2) 0           tf_op_layer_ExpandDims_690[0][0]
#                                                                  tf_op_layer_ExpandDims_691[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_692 (Ten [(None, 218, 170, 1) 0           lambda_500[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_693 (Ten [(None, 218, 170, 1) 0           lambda_501[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Add_66 (TensorFlowO [(None, 218, 170, 2) 0           tf_op_layer_Add_65[0][0]
#                                                                  tf_op_layer_concat_346[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_347 (TensorF [(None, 218, 170, 2) 0           tf_op_layer_ExpandDims_692[0][0]
#                                                                  tf_op_layer_ExpandDims_693[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Add_67 (TensorFlowO [(None, 218, 170, 2) 0           tf_op_layer_Add_66[0][0]
#                                                                  tf_op_layer_concat_347[0][0]
# __________________________________________________________________________________________________
# lambda_502 (Lambda)             (None, 218, 170, 2)  0           tf_op_layer_Add_67[0][0]
# ==================================================================================================
# Total params: 12,002,696
# Trainable params: 12,002,696
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
