# %%
# Importing standard libraries
import numpy as np
import os
import glob
import sys
import importlib
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import  Adam
from tensorflow.keras.models import load_model
import pickle
import tensorflow as tf
from skimage.morphology import area_opening

# Include path to my modules
MY_UTILS_PATH = "../Modules/"
if not MY_UTILS_PATH in sys.path:
    sys.path.append(MY_UTILS_PATH)

# Import my modules
import cs_models_mc_combined as fsnet
importlib.reload(fsnet)
import cs_models_mc_combined as fsnet
from data_generator_mc_combined import DataGenerator

physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# Input parameters
H = 218
W = 170
channels = 12
batch_size = 8
epochs = 1
lr = 1e-4
patience = 10
sampling_mask_path = "../Data/poisson_sampling/R5_218x170.npy"
model_path =  "../Models/model_wwnet_ikik_mcc_r5.h5"
weights_path = "../Models/weights_wwnet_ikik_mcc_r5.h5"
model_string = "ikik"
train_path = "../../data/train_val_12_channel/Train/"
val_path = "../../data/train_val_12_channel/Val/"
cascade = "unet"
nslices = 256
crop = (15, 15)
verbose = True

# %%
train = glob.glob(train_path + "*.h5")
val = glob.glob(val_path + "*.h5")

# undersampling patterns - centered k-space - 100 pre computed patterns
var_sampling_mask = np.load(sampling_mask_path)

acs = area_opening(var_sampling_mask[0], area_threshold=10, connectivity=1, parent=None, tree_traverser=None)


if verbose:
    print(cascade)
    print("Domains: ", model_string)
    print("Model name: ", model_path)
    print("Weights path: ", weights_path)
    print("Sampling:", 1.0*var_sampling_mask.sum() / (var_sampling_mask.size*0.85)) # 85 % sampling Kz direction
    print("Train path: ", train_path)
    print("Validation path: ", val_path)


# Replicate sampling mask across number of channels
var_sampling_mask = np.repeat(var_sampling_mask[:, :, :, np.newaxis], 24, axis = -1) 

train_generator = DataGenerator(train, dim = (H, W), under_masks = var_sampling_mask,  crop = crop,\
                            batch_size = batch_size, n_channels = channels * 2, nslices = nslices, shuffle=True, acs = acs)

val_generator = DataGenerator(val, dim = (H, W), under_masks = var_sampling_mask,  crop = crop,\
                            batch_size = batch_size, n_channels = channels * 2, nslices= nslices, shuffle=False, acs = acs)



# Callbacks
earlyStopping = EarlyStopping(monitor='val_loss',
                                           patience=patience, 
                                           verbose=0, mode='min')

checkpoint = ModelCheckpoint(weights_path, mode = 'min', \
                             monitor='val_loss',verbose=0,\
                             save_best_only=True, save_weights_only = True)

checkpoint2 = ModelCheckpoint(model_path, monitor='val_loss', verbose=0, save_best_only=False,\
                save_weights_only=False, mode='min')

Hpad = (8 - (H%8)) // 2
Wpad = (8 - (W%8)) // 2
if os.path.isfile(model_path):
    model = load_model(model_path)
elif  cascade == 'unet':
    model = fsnet.deep_cascade_unet(depth_str = model_string, H = H, W = W, Hpad = Hpad, Wpad = Wpad, channels = channels) 
elif cascade == 'flat':
    model = fsnet.deep_cascade_flat_unrolled(depth_str = model_string, H = H,W = W,depth = 6, kshape = (3,3), nf = 64,channels = channels)
else:
   pass

if not os.path.isfile(model_path):
    opt = Adam(learning_rate = lr)
    model.compile(loss = 'mse',optimizer=opt)

if verbose:
    print(model.summary())

hist = model.fit(train_generator, epochs = epochs, steps_per_epoch = ( (nslices - crop[0] - crop[1])*len(train) ) // batch_size, \
             validation_data = val_generator, validation_steps = ( (nslices - crop[0] - crop[1])*len(val) ) // batch_size, \
                   callbacks = [ checkpoint2, checkpoint, earlyStopping ], verbose = 1)

# Save model history
with open(model_path[:-2] + "history", 'wb') as file_pi:
    pickle.dump(hist.history, file_pi)
# Out:
# unet
# Domains:  ikik
# Model name:  ../Models/model_wwnet_ikik_mcc_r5.h5
# Weights path:  ../Models/weights_wwnet_ikik_mcc_r5.h5
# Sampling: 0.2008279102250722
# Train path:  ../../data/train_val_12_channel/Train/
# Validation path:  ../../data/train_val_12_channel/Val/
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 218, 170, 2) 0
# __________________________________________________________________________________________________
# lambda_102 (Lambda)             (None, 218, 170, 2)  0           input_9[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 224, 176, 2)  0           lambda_102[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 224, 176, 48) 912         zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 224, 176, 48) 20784       conv2d_110[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 224, 176, 48) 20784       conv2d_111[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 112, 88, 48)  0           conv2d_112[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 112, 88, 64)  27712       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 112, 88, 64)  36928       conv2d_113[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 112, 88, 64)  36928       conv2d_114[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 56, 44, 64)   0           conv2d_115[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 56, 44, 128)  73856       max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 56, 44, 128)  147584      conv2d_116[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 56, 44, 128)  147584      conv2d_117[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 28, 22, 128)  0           conv2d_118[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 28, 22, 256)  295168      max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 28, 22, 256)  590080      conv2d_119[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 28, 22, 256)  590080      conv2d_120[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 56, 44, 256)  0           conv2d_121[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 56, 44, 384)  0           up_sampling2d_15[0][0]
#                                                                  conv2d_118[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 56, 44, 128)  442496      concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 56, 44, 128)  147584      conv2d_122[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 56, 44, 128)  147584      conv2d_123[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_16 (UpSampling2D) (None, 112, 88, 128) 0           conv2d_124[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 112, 88, 192) 0           up_sampling2d_16[0][0]
#                                                                  conv2d_115[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 112, 88, 64)  110656      concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 112, 88, 64)  36928       conv2d_125[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 112, 88, 64)  36928       conv2d_126[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_17 (UpSampling2D) (None, 224, 176, 64) 0           conv2d_127[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 224, 176, 112 0           up_sampling2d_17[0][0]
#                                                                  conv2d_112[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 224, 176, 48) 48432       concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 224, 176, 48) 20784       conv2d_128[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 224, 176, 48) 20784       conv2d_129[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 224, 176, 2)  98          conv2d_130[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 224, 176, 2)  0           conv2d_131[0][0]
#                                                                  zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# cropping2d_5 (Cropping2D)       (None, 218, 170, 2)  0           add_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_114 ( (None, 218, 170)     0           cropping2d_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_115 ( (None, 218, 170)     0           cropping2d_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_53 (TensorF (None, 218, 170)     0           tf_op_layer_strided_slice_114[0][
#                                                                  tf_op_layer_strided_slice_115[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_205 (Ten (None, 218, 170, 1)  0           tf_op_layer_Complex_53[0][0]
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 218, 170, 12 0
# __________________________________________________________________________________________________
# tf_op_layer_Mul_4 (TensorFlowOp (None, 218, 170, 12) 0           tf_op_layer_ExpandDims_205[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_52 (TensorFlow (None, 218, 170, 12) 0           tf_op_layer_Mul_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_52 (TensorFlow (None, 218, 170, 12) 0           tf_op_layer_Mul_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_116 ( (None, 218, 170)     0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_117 ( (None, 218, 170)     0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_118 ( (None, 218, 170)     0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_119 ( (None, 218, 170)     0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_120 ( (None, 218, 170)     0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_121 ( (None, 218, 170)     0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_122 ( (None, 218, 170)     0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_123 ( (None, 218, 170)     0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_124 ( (None, 218, 170)     0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_125 ( (None, 218, 170)     0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_126 ( (None, 218, 170)     0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_127 ( (None, 218, 170)     0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_128 ( (None, 218, 170)     0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_129 ( (None, 218, 170)     0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_130 ( (None, 218, 170)     0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_131 ( (None, 218, 170)     0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_132 ( (None, 218, 170)     0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_133 ( (None, 218, 170)     0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_134 ( (None, 218, 170)     0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_135 ( (None, 218, 170)     0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_136 ( (None, 218, 170)     0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_137 ( (None, 218, 170)     0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_138 ( (None, 218, 170)     0           tf_op_layer_Real_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_139 ( (None, 218, 170)     0           tf_op_layer_Imag_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_206 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_116[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_207 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_117[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_208 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_118[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_209 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_119[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_210 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_120[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_211 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_121[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_212 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_122[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_213 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_123[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_214 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_124[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_215 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_125[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_216 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_126[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_217 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_127[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_218 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_128[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_219 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_129[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_220 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_130[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_221 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_131[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_222 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_132[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_223 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_133[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_224 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_134[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_225 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_135[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_226 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_136[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_227 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_137[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_228 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_138[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_229 (Ten (None, 218, 170, 1)  0           tf_op_layer_strided_slice_139[0][
# __________________________________________________________________________________________________
# tf_op_layer_concat_56 (TensorFl (None, 218, 170, 24) 0           tf_op_layer_ExpandDims_206[0][0]
#                                                                  tf_op_layer_ExpandDims_207[0][0]
#                                                                  tf_op_layer_ExpandDims_208[0][0]
#                                                                  tf_op_layer_ExpandDims_209[0][0]
#                                                                  tf_op_layer_ExpandDims_210[0][0]
#                                                                  tf_op_layer_ExpandDims_211[0][0]
#                                                                  tf_op_layer_ExpandDims_212[0][0]
#                                                                  tf_op_layer_ExpandDims_213[0][0]
#                                                                  tf_op_layer_ExpandDims_214[0][0]
#                                                                  tf_op_layer_ExpandDims_215[0][0]
#                                                                  tf_op_layer_ExpandDims_216[0][0]
#                                                                  tf_op_layer_ExpandDims_217[0][0]
#                                                                  tf_op_layer_ExpandDims_218[0][0]
#                                                                  tf_op_layer_ExpandDims_219[0][0]
#                                                                  tf_op_layer_ExpandDims_220[0][0]
#                                                                  tf_op_layer_ExpandDims_221[0][0]
#                                                                  tf_op_layer_ExpandDims_222[0][0]
#                                                                  tf_op_layer_ExpandDims_223[0][0]
#                                                                  tf_op_layer_ExpandDims_224[0][0]
#                                                                  tf_op_layer_ExpandDims_225[0][0]
#                                                                  tf_op_layer_ExpandDims_226[0][0]
#                                                                  tf_op_layer_ExpandDims_227[0][0]
#                                                                  tf_op_layer_ExpandDims_228[0][0]
#                                                                  tf_op_layer_ExpandDims_229[0][0]
# __________________________________________________________________________________________________
# lambda_103 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# lambda_104 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_54 (TensorF (None, 218, 170)     0           lambda_103[0][0]
#                                                                  lambda_104[0][0]
# __________________________________________________________________________________________________
# lambda_105 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# lambda_106 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_48 (TensorFlo (None, 218, 170)     0           tf_op_layer_Complex_54[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_55 (TensorF (None, 218, 170)     0           lambda_105[0][0]
#                                                                  lambda_106[0][0]
# __________________________________________________________________________________________________
# lambda_107 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# lambda_108 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_53 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_48[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_53 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_48[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_49 (TensorFlo (None, 218, 170)     0           tf_op_layer_Complex_55[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_56 (TensorF (None, 218, 170)     0           lambda_107[0][0]
#                                                                  lambda_108[0][0]
# __________________________________________________________________________________________________
# lambda_109 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# lambda_110 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_230 (Ten (None, 218, 170, 1)  0           tf_op_layer_Real_53[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_231 (Ten (None, 218, 170, 1)  0           tf_op_layer_Imag_53[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_54 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_49[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_54 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_49[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_50 (TensorFlo (None, 218, 170)     0           tf_op_layer_Complex_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_57 (TensorF (None, 218, 170)     0           lambda_109[0][0]
#                                                                  lambda_110[0][0]
# __________________________________________________________________________________________________
# lambda_111 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# lambda_112 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_57 (TensorFl (None, 218, 170, 2)  0           tf_op_layer_ExpandDims_230[0][0]
#                                                                  tf_op_layer_ExpandDims_231[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_232 (Ten (None, 218, 170, 1)  0           tf_op_layer_Real_54[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_233 (Ten (None, 218, 170, 1)  0           tf_op_layer_Imag_54[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_55 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_50[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_55 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_50[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_51 (TensorFlo (None, 218, 170)     0           tf_op_layer_Complex_57[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_58 (TensorF (None, 218, 170)     0           lambda_111[0][0]
#                                                                  lambda_112[0][0]
# __________________________________________________________________________________________________
# lambda_113 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# lambda_114 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_58 (TensorFl (None, 218, 170, 4)  0           tf_op_layer_concat_57[0][0]
#                                                                  tf_op_layer_ExpandDims_232[0][0]
#                                                                  tf_op_layer_ExpandDims_233[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_234 (Ten (None, 218, 170, 1)  0           tf_op_layer_Real_55[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_235 (Ten (None, 218, 170, 1)  0           tf_op_layer_Imag_55[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_56 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_51[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_56 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_51[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_52 (TensorFlo (None, 218, 170)     0           tf_op_layer_Complex_58[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_59 (TensorF (None, 218, 170)     0           lambda_113[0][0]
#                                                                  lambda_114[0][0]
# __________________________________________________________________________________________________
# lambda_115 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# lambda_116 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_59 (TensorFl (None, 218, 170, 6)  0           tf_op_layer_concat_58[0][0]
#                                                                  tf_op_layer_ExpandDims_234[0][0]
#                                                                  tf_op_layer_ExpandDims_235[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_236 (Ten (None, 218, 170, 1)  0           tf_op_layer_Real_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_237 (Ten (None, 218, 170, 1)  0           tf_op_layer_Imag_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_57 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_57 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_53 (TensorFlo (None, 218, 170)     0           tf_op_layer_Complex_59[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_60 (TensorF (None, 218, 170)     0           lambda_115[0][0]
#                                                                  lambda_116[0][0]
# __________________________________________________________________________________________________
# lambda_117 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# lambda_118 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_60 (TensorFl (None, 218, 170, 8)  0           tf_op_layer_concat_59[0][0]
#                                                                  tf_op_layer_ExpandDims_236[0][0]
#                                                                  tf_op_layer_ExpandDims_237[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_238 (Ten (None, 218, 170, 1)  0           tf_op_layer_Real_57[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_239 (Ten (None, 218, 170, 1)  0           tf_op_layer_Imag_57[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_58 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_53[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_58 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_53[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_54 (TensorFlo (None, 218, 170)     0           tf_op_layer_Complex_60[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_61 (TensorF (None, 218, 170)     0           lambda_117[0][0]
#                                                                  lambda_118[0][0]
# __________________________________________________________________________________________________
# lambda_119 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# lambda_120 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_61 (TensorFl (None, 218, 170, 10) 0           tf_op_layer_concat_60[0][0]
#                                                                  tf_op_layer_ExpandDims_238[0][0]
#                                                                  tf_op_layer_ExpandDims_239[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_240 (Ten (None, 218, 170, 1)  0           tf_op_layer_Real_58[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_241 (Ten (None, 218, 170, 1)  0           tf_op_layer_Imag_58[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_59 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_54[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_59 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_54[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_55 (TensorFlo (None, 218, 170)     0           tf_op_layer_Complex_61[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_62 (TensorF (None, 218, 170)     0           lambda_119[0][0]
#                                                                  lambda_120[0][0]
# __________________________________________________________________________________________________
# lambda_121 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# lambda_122 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_62 (TensorFl (None, 218, 170, 12) 0           tf_op_layer_concat_61[0][0]
#                                                                  tf_op_layer_ExpandDims_240[0][0]
#                                                                  tf_op_layer_ExpandDims_241[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_242 (Ten (None, 218, 170, 1)  0           tf_op_layer_Real_59[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_243 (Ten (None, 218, 170, 1)  0           tf_op_layer_Imag_59[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_60 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_55[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_60 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_55[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_56 (TensorFlo (None, 218, 170)     0           tf_op_layer_Complex_62[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_63 (TensorF (None, 218, 170)     0           lambda_121[0][0]
#                                                                  lambda_122[0][0]
# __________________________________________________________________________________________________
# lambda_123 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# lambda_124 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_63 (TensorFl (None, 218, 170, 14) 0           tf_op_layer_concat_62[0][0]
#                                                                  tf_op_layer_ExpandDims_242[0][0]
#                                                                  tf_op_layer_ExpandDims_243[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_244 (Ten (None, 218, 170, 1)  0           tf_op_layer_Real_60[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_245 (Ten (None, 218, 170, 1)  0           tf_op_layer_Imag_60[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_61 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_61 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_57 (TensorFlo (None, 218, 170)     0           tf_op_layer_Complex_63[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_64 (TensorF (None, 218, 170)     0           lambda_123[0][0]
#                                                                  lambda_124[0][0]
# __________________________________________________________________________________________________
# lambda_125 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# lambda_126 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_64 (TensorFl (None, 218, 170, 16) 0           tf_op_layer_concat_63[0][0]
#                                                                  tf_op_layer_ExpandDims_244[0][0]
#                                                                  tf_op_layer_ExpandDims_245[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_246 (Ten (None, 218, 170, 1)  0           tf_op_layer_Real_61[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_247 (Ten (None, 218, 170, 1)  0           tf_op_layer_Imag_61[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_62 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_57[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_62 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_57[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_58 (TensorFlo (None, 218, 170)     0           tf_op_layer_Complex_64[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_65 (TensorF (None, 218, 170)     0           lambda_125[0][0]
#                                                                  lambda_126[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_65 (TensorFl (None, 218, 170, 18) 0           tf_op_layer_concat_64[0][0]
#                                                                  tf_op_layer_ExpandDims_246[0][0]
#                                                                  tf_op_layer_ExpandDims_247[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_248 (Ten (None, 218, 170, 1)  0           tf_op_layer_Real_62[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_249 (Ten (None, 218, 170, 1)  0           tf_op_layer_Imag_62[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_63 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_58[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_63 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_58[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_59 (TensorFlo (None, 218, 170)     0           tf_op_layer_Complex_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_66 (TensorFl (None, 218, 170, 20) 0           tf_op_layer_concat_65[0][0]
#                                                                  tf_op_layer_ExpandDims_248[0][0]
#                                                                  tf_op_layer_ExpandDims_249[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_250 (Ten (None, 218, 170, 1)  0           tf_op_layer_Real_63[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_251 (Ten (None, 218, 170, 1)  0           tf_op_layer_Imag_63[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_64 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_59[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_64 (TensorFlow (None, 218, 170)     0           tf_op_layer_FFT2D_59[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_67 (TensorFl (None, 218, 170, 22) 0           tf_op_layer_concat_66[0][0]
#                                                                  tf_op_layer_ExpandDims_250[0][0]
#                                                                  tf_op_layer_ExpandDims_251[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_252 (Ten (None, 218, 170, 1)  0           tf_op_layer_Real_64[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_253 (Ten (None, 218, 170, 1)  0           tf_op_layer_Imag_64[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_68 (TensorFl (None, 218, 170, 24) 0           tf_op_layer_concat_67[0][0]
#                                                                  tf_op_layer_ExpandDims_252[0][0]
#                                                                  tf_op_layer_ExpandDims_253[0][0]
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 218, 170, 24 0
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 218, 170, 24) 0           tf_op_layer_concat_68[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 218, 170, 24 0
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 218, 170, 24) 0           multiply_4[0][0]
#                                                                  input_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_140 ( (None, 218, 170, 12) 0           add_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_141 ( (None, 218, 170, 12) 0           add_10[0][0]
# ...
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_397 (Ten (None, 218, 170, 1)  0           tf_op_layer_Real_99[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_398 (Ten (None, 218, 170, 1)  0           tf_op_layer_Imag_99[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_100 (TensorFlo (None, 218, 170)     0           tf_op_layer_FFT2D_92[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_100 (TensorFlo (None, 218, 170)     0           tf_op_layer_FFT2D_92[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_93 (TensorFlo (None, 218, 170)     0           tf_op_layer_Complex_102[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_103 (Tensor (None, 218, 170)     0           lambda_198[0][0]
#                                                                  lambda_199[0][0]
# __________________________________________________________________________________________________
# lambda_200 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_98[0][0]
# __________________________________________________________________________________________________
# lambda_201 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_98[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_106 (TensorF (None, 218, 170, 16) 0           tf_op_layer_concat_105[0][0]
#                                                                  tf_op_layer_ExpandDims_397[0][0]
#                                                                  tf_op_layer_ExpandDims_398[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_399 (Ten (None, 218, 170, 1)  0           tf_op_layer_Real_100[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_400 (Ten (None, 218, 170, 1)  0           tf_op_layer_Imag_100[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_101 (TensorFlo (None, 218, 170)     0           tf_op_layer_FFT2D_93[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_101 (TensorFlo (None, 218, 170)     0           tf_op_layer_FFT2D_93[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_94 (TensorFlo (None, 218, 170)     0           tf_op_layer_Complex_103[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_104 (Tensor (None, 218, 170)     0           lambda_200[0][0]
#                                                                  lambda_201[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_107 (TensorF (None, 218, 170, 18) 0           tf_op_layer_concat_106[0][0]
#                                                                  tf_op_layer_ExpandDims_399[0][0]
#                                                                  tf_op_layer_ExpandDims_400[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_401 (Ten (None, 218, 170, 1)  0           tf_op_layer_Real_101[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_402 (Ten (None, 218, 170, 1)  0           tf_op_layer_Imag_101[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_102 (TensorFlo (None, 218, 170)     0           tf_op_layer_FFT2D_94[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_102 (TensorFlo (None, 218, 170)     0           tf_op_layer_FFT2D_94[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_95 (TensorFlo (None, 218, 170)     0           tf_op_layer_Complex_104[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_108 (TensorF (None, 218, 170, 20) 0           tf_op_layer_concat_107[0][0]
#                                                                  tf_op_layer_ExpandDims_401[0][0]
#                                                                  tf_op_layer_ExpandDims_402[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_403 (Ten (None, 218, 170, 1)  0           tf_op_layer_Real_102[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_404 (Ten (None, 218, 170, 1)  0           tf_op_layer_Imag_102[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_103 (TensorFlo (None, 218, 170)     0           tf_op_layer_FFT2D_95[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_103 (TensorFlo (None, 218, 170)     0           tf_op_layer_FFT2D_95[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_109 (TensorF (None, 218, 170, 22) 0           tf_op_layer_concat_108[0][0]
#                                                                  tf_op_layer_ExpandDims_403[0][0]
#                                                                  tf_op_layer_ExpandDims_404[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_405 (Ten (None, 218, 170, 1)  0           tf_op_layer_Real_103[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_406 (Ten (None, 218, 170, 1)  0           tf_op_layer_Imag_103[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_110 (TensorF (None, 218, 170, 24) 0           tf_op_layer_concat_109[0][0]
#                                                                  tf_op_layer_ExpandDims_405[0][0]
#                                                                  tf_op_layer_ExpandDims_406[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 218, 170, 24) 0           tf_op_layer_concat_110[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 218, 170, 24) 0           multiply_7[0][0]
#                                                                  input_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_224 ( (None, 218, 170, 12) 0           add_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_225 ( (None, 218, 170, 12) 0           add_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_14 (TensorFlowO (None, 218, 170)     0           tf_op_layer_strided_slice_224[0][
# __________________________________________________________________________________________________
# tf_op_layer_Sum_15 (TensorFlowO (None, 218, 170)     0           tf_op_layer_strided_slice_225[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_407 (Ten (None, 218, 170, 1)  0           tf_op_layer_Sum_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_408 (Ten (None, 218, 170, 1)  0           tf_op_layer_Sum_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_111 (TensorF (None, 218, 170, 2)  0           tf_op_layer_ExpandDims_407[0][0]
#                                                                  tf_op_layer_ExpandDims_408[0][0]
# __________________________________________________________________________________________________
# lambda_202 (Lambda)             (None, 218, 170, 2)  0           tf_op_layer_concat_111[0][0]
# ==================================================================================================
# Total params: 12,002,696
# Trainable params: 12,002,696
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 1327 steps, validate for 565 steps
#    1/1327 [..............................] - ETA: 8:02:50WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are:
#    1/1327 [..............................] - ETA: 8:18:52
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-12-c197ba5bcb19> in <module>()
#      54     print(model.summary())
#      55
# ---> 56 hist = model.fit(train_generator, epochs = epochs, steps_per_epoch = ( (nslices - crop[0] - crop[1])*len(train) ) // batch_size,              validation_data = val_generator, validation_steps = ( (nslices - crop[0] - crop[1])*len(val) ) // batch_size,                    callbacks = [ checkpoint2, checkpoint, earlyStopping ], verbose = 1)
#      57
#      58 # Save model history
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\eager\def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\eager\def_function.py in _call(self, *args, **kwds)
#     636               *args, **kwds)
#     637       # If we did not create any variables the trace we have is good enough.
# --> 638       return self._concrete_stateful_fn._filtered_call(canon_args, canon_kwds)  # pylint: disable=protected-access
#     639
#     640     def fn_with_cond(*inner_args, **inner_kwds):
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      65     else:
#      66       message = e.message
# ---> 67     six.raise_from(core._status_to_exception(e.code, message), None)
#      68   except TypeError as e:
#      69     keras_symbolic_tensors = [
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\six.py in raise_from(value, from_value)
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[8,224,176,64] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node model_1/up_sampling2d_17/resize/ResizeNearestNeighbor (defined at <ipython-input-12-c197ba5bcb19>:56) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_distributed_function_62583]
#
# Function call stack:
# distributed_function
