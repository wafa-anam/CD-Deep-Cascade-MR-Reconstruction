# %%
# Importing standard libraries
import numpy as np
import os
import glob
import sys
import importlib
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import  Adam
from tensorflow.keras.models import load_model
import pickle
import tensorflow as tf
from skimage.morphology import area_opening

# Include path to my modules
MY_UTILS_PATH = "../Modules/"
if not MY_UTILS_PATH in sys.path:
    sys.path.append(MY_UTILS_PATH)

# Import my modules
import cs_models_mc_combined as fsnet
importlib.reload(fsnet)
import cs_models_mc_combined as fsnet
from data_generator_mc_combined import DataGenerator

physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# Input parameters
H = 218
W = 170
channels = 12
batch_size = 8
epochs = 1
lr = 1e-4
patience = 10
sampling_mask_path = "../Data/poisson_sampling/R5_218x170.npy"
model_path =  "../Models/model_wwnet_ikik_mcc_r5.h5"
weights_path = "../Models/weights_wwnet_ikik_mcc_r5.h5"
model_string = "ikik"
train_path = "../../MR_data/train_val_12_channel/Train/"
val_path = "../../MR_data/train_val_12_channel/Val/"
cascade = "unet"
nslices = 256
crop = (15, 15)
verbose = True

# %%
train = glob.glob(train_path + "*.h5")
val = glob.glob(val_path + "*.h5")

# undersampling patterns - centered k-space - 100 pre computed patterns
var_sampling_mask = np.load(sampling_mask_path)

acs = area_opening(var_sampling_mask[0], area_threshold=10, connectivity=1, parent=None, tree_traverser=None)


if verbose:
    print(cascade)
    print("Domains: ", model_string)
    print("Model name: ", model_path)
    print("Weights path: ", weights_path)
    print("Sampling:", 1.0*var_sampling_mask.sum() / (var_sampling_mask.size*0.85)) # 85 % sampling Kz direction
    print("Train path: ", train_path)
    print("Validation path: ", val_path)


# Replicate sampling mask across number of channels
var_sampling_mask = np.repeat(var_sampling_mask[:, :, :, np.newaxis], 24, axis = -1) 

train_generator = DataGenerator(train, dim = (H, W), under_masks = var_sampling_mask,  crop = crop,\
                            batch_size = batch_size, n_channels = channels * 2, nslices = nslices, shuffle=True, acs = acs)

val_generator = DataGenerator(val, dim = (H, W), under_masks = var_sampling_mask,  crop = crop,\
                            batch_size = batch_size, n_channels = channels * 2, nslices= nslices, shuffle=False, acs = acs)



# Callbacks
earlyStopping = EarlyStopping(monitor='val_loss',
                                           patience=patience, 
                                           verbose=0, mode='min')

checkpoint = ModelCheckpoint(weights_path, mode = 'min', \
                             monitor='val_loss',verbose=0,\
                             save_best_only=True, save_weights_only = True)

checkpoint2 = ModelCheckpoint(model_path, monitor='val_loss', verbose=0, save_best_only=False,\
                save_weights_only=False, mode='min')

Hpad = (8 - (H%8)) // 2
Wpad = (8 - (W%8)) // 2
if os.path.isfile(model_path):
    model = load_model(model_path)
elif  cascade == 'unet':
    model = fsnet.deep_cascade_unet(depth_str = model_string, H = H, W = W, Hpad = Hpad, Wpad = Wpad, channels = channels) 
elif cascade == 'flat':
    model = fsnet.deep_cascade_flat_unrolled(depth_str = model_string, H = H,W = W,depth = 6, kshape = (3,3), nf = 64,channels = channels)
else:
   pass

if not os.path.isfile(model_path):
    opt = Adam(learning_rate = lr)
    model.compile(loss = 'mse',optimizer=opt)

if verbose:
    print(model.summary())

hist = model.fit(train_generator, epochs = epochs, steps_per_epoch = ( (nslices - crop[0] - crop[1])*len(train) ) // batch_size, \
             validation_data = val_generator, validation_steps = ( (nslices - crop[0] - crop[1])*len(val) ) // batch_size, \
                   callbacks = [ checkpoint2, checkpoint, earlyStopping ], verbose = 1)

# Save model history
with open(model_path[:-2] + "history", 'wb') as file_pi:
    pickle.dump(hist.history, file_pi)
# Out:
# unet
# Domains:  ikik
# Model name:  ../Models/model_wwnet_ikik_mcc_r5.h5
# Weights path:  ../Models/weights_wwnet_ikik_mcc_r5.h5
# Sampling: 0.2008279102250722
# Train path:  ../../MR_data/train_val_12_channel/Train/
# Validation path:  ../../MR_data/train_val_12_channel/Val/
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 218, 170, 2) 0
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 218, 170, 2)  0           input_9[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 224, 176, 2)  0           lambda_27[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 224, 176, 48) 912         zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 224, 176, 48) 20784       conv2d_66[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 224, 176, 48) 20784       conv2d_67[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 112, 88, 48)  0           conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 112, 88, 64)  27712       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 112, 88, 64)  36928       conv2d_69[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 112, 88, 64)  36928       conv2d_70[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 56, 44, 64)   0           conv2d_71[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 56, 44, 128)  73856       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 56, 44, 128)  147584      conv2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 56, 44, 128)  147584      conv2d_73[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 28, 22, 128)  0           conv2d_74[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 28, 22, 256)  295168      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 28, 22, 256)  590080      conv2d_75[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 28, 22, 256)  590080      conv2d_76[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 56, 44, 256)  0           conv2d_77[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 56, 44, 384)  0           up_sampling2d_9[0][0]
#                                                                  conv2d_74[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 56, 44, 128)  442496      concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 56, 44, 128)  147584      conv2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 56, 44, 128)  147584      conv2d_79[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 112, 88, 128) 0           conv2d_80[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 112, 88, 192) 0           up_sampling2d_10[0][0]
#                                                                  conv2d_71[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 112, 88, 64)  110656      concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 112, 88, 64)  36928       conv2d_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 112, 88, 64)  36928       conv2d_82[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 224, 176, 64) 0           conv2d_83[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 224, 176, 112 0           up_sampling2d_11[0][0]
#                                                                  conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 224, 176, 48) 48432       concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 224, 176, 48) 20784       conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 224, 176, 48) 20784       conv2d_85[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 224, 176, 2)  98          conv2d_86[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 224, 176, 2)  0           conv2d_87[0][0]
#                                                                  zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# cropping2d_3 (Cropping2D)       (None, 218, 170, 2)  0           add_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_32 (T [(None, 218, 170)]   0           cropping2d_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_33 (T [(None, 218, 170)]   0           cropping2d_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_15 (TensorF [(None, 218, 170)]   0           tf_op_layer_strided_slice_32[0][0
#                                                                  tf_op_layer_strided_slice_33[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_53 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Complex_15[0][0]
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 218, 170, 12 0
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1 (TensorFlowOp [(None, 218, 170, 12 0           tf_op_layer_ExpandDims_53[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_13 (TensorFlow [(None, 218, 170, 12 0           tf_op_layer_Mul_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_13 (TensorFlow [(None, 218, 170, 12 0           tf_op_layer_Mul_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_34 (T [(None, 218, 170)]   0           tf_op_layer_Real_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_35 (T [(None, 218, 170)]   0           tf_op_layer_Imag_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_36 (T [(None, 218, 170)]   0           tf_op_layer_Real_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_37 (T [(None, 218, 170)]   0           tf_op_layer_Imag_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_38 (T [(None, 218, 170)]   0           tf_op_layer_Real_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_39 (T [(None, 218, 170)]   0           tf_op_layer_Imag_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_40 (T [(None, 218, 170)]   0           tf_op_layer_Real_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_41 (T [(None, 218, 170)]   0           tf_op_layer_Imag_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_42 (T [(None, 218, 170)]   0           tf_op_layer_Real_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_43 (T [(None, 218, 170)]   0           tf_op_layer_Imag_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_44 (T [(None, 218, 170)]   0           tf_op_layer_Real_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_45 (T [(None, 218, 170)]   0           tf_op_layer_Imag_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_46 (T [(None, 218, 170)]   0           tf_op_layer_Real_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_47 (T [(None, 218, 170)]   0           tf_op_layer_Imag_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_48 (T [(None, 218, 170)]   0           tf_op_layer_Real_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_49 (T [(None, 218, 170)]   0           tf_op_layer_Imag_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_50 (T [(None, 218, 170)]   0           tf_op_layer_Real_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_51 (T [(None, 218, 170)]   0           tf_op_layer_Imag_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_52 (T [(None, 218, 170)]   0           tf_op_layer_Real_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_53 (T [(None, 218, 170)]   0           tf_op_layer_Imag_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_54 (T [(None, 218, 170)]   0           tf_op_layer_Real_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_55 (T [(None, 218, 170)]   0           tf_op_layer_Imag_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_56 (T [(None, 218, 170)]   0           tf_op_layer_Real_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_57 (T [(None, 218, 170)]   0           tf_op_layer_Imag_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_54 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_34[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_55 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_35[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_56 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_36[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_57 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_37[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_58 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_38[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_59 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_39[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_60 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_40[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_61 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_41[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_62 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_42[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_63 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_43[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_64 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_44[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_65 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_45[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_66 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_46[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_67 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_47[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_68 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_48[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_69 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_49[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_70 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_50[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_71 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_51[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_72 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_52[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_73 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_53[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_74 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_54[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_75 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_55[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_76 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_56[0][0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_77 (Tens [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_57[0][0
# __________________________________________________________________________________________________
# tf_op_layer_concat_14 (TensorFl [(None, 218, 170, 24 0           tf_op_layer_ExpandDims_54[0][0]
#                                                                  tf_op_layer_ExpandDims_55[0][0]
#                                                                  tf_op_layer_ExpandDims_56[0][0]
#                                                                  tf_op_layer_ExpandDims_57[0][0]
#                                                                  tf_op_layer_ExpandDims_58[0][0]
#                                                                  tf_op_layer_ExpandDims_59[0][0]
#                                                                  tf_op_layer_ExpandDims_60[0][0]
#                                                                  tf_op_layer_ExpandDims_61[0][0]
#                                                                  tf_op_layer_ExpandDims_62[0][0]
#                                                                  tf_op_layer_ExpandDims_63[0][0]
#                                                                  tf_op_layer_ExpandDims_64[0][0]
#                                                                  tf_op_layer_ExpandDims_65[0][0]
#                                                                  tf_op_layer_ExpandDims_66[0][0]
#                                                                  tf_op_layer_ExpandDims_67[0][0]
#                                                                  tf_op_layer_ExpandDims_68[0][0]
#                                                                  tf_op_layer_ExpandDims_69[0][0]
#                                                                  tf_op_layer_ExpandDims_70[0][0]
#                                                                  tf_op_layer_ExpandDims_71[0][0]
#                                                                  tf_op_layer_ExpandDims_72[0][0]
#                                                                  tf_op_layer_ExpandDims_73[0][0]
#                                                                  tf_op_layer_ExpandDims_74[0][0]
#                                                                  tf_op_layer_ExpandDims_75[0][0]
#                                                                  tf_op_layer_ExpandDims_76[0][0]
#                                                                  tf_op_layer_ExpandDims_77[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_16 (TensorF [(None, 218, 170)]   0           lambda_28[0][0]
#                                                                  lambda_29[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_12 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_17 (TensorF [(None, 218, 170)]   0           lambda_30[0][0]
#                                                                  lambda_31[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_14 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_14 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_13 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_18 (TensorF [(None, 218, 170)]   0           lambda_32[0][0]
#                                                                  lambda_33[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_78 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Real_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_79 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Imag_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_15 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_15 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_14 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_19 (TensorF [(None, 218, 170)]   0           lambda_34[0][0]
#                                                                  lambda_35[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_15 (TensorFl [(None, 218, 170, 2) 0           tf_op_layer_ExpandDims_78[0][0]
#                                                                  tf_op_layer_ExpandDims_79[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_80 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Real_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_81 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Imag_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_16 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_16 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_15 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_20 (TensorF [(None, 218, 170)]   0           lambda_36[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_16 (TensorFl [(None, 218, 170, 4) 0           tf_op_layer_concat_15[0][0]
#                                                                  tf_op_layer_ExpandDims_80[0][0]
#                                                                  tf_op_layer_ExpandDims_81[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_82 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Real_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_83 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Imag_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_17 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_17 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_16 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_21 (TensorF [(None, 218, 170)]   0           lambda_38[0][0]
#                                                                  lambda_39[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_17 (TensorFl [(None, 218, 170, 6) 0           tf_op_layer_concat_16[0][0]
#                                                                  tf_op_layer_ExpandDims_82[0][0]
#                                                                  tf_op_layer_ExpandDims_83[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_84 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Real_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_85 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Imag_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_18 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_18 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_17 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_22 (TensorF [(None, 218, 170)]   0           lambda_40[0][0]
#                                                                  lambda_41[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_18 (TensorFl [(None, 218, 170, 8) 0           tf_op_layer_concat_17[0][0]
#                                                                  tf_op_layer_ExpandDims_84[0][0]
#                                                                  tf_op_layer_ExpandDims_85[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_86 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Real_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_87 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Imag_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_19 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_19 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_18 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_23 (TensorF [(None, 218, 170)]   0           lambda_42[0][0]
#                                                                  lambda_43[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_19 (TensorFl [(None, 218, 170, 10 0           tf_op_layer_concat_18[0][0]
#                                                                  tf_op_layer_ExpandDims_86[0][0]
#                                                                  tf_op_layer_ExpandDims_87[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_88 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Real_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_89 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Imag_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_20 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_20 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_19 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_24 (TensorF [(None, 218, 170)]   0           lambda_44[0][0]
#                                                                  lambda_45[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_20 (TensorFl [(None, 218, 170, 12 0           tf_op_layer_concat_19[0][0]
#                                                                  tf_op_layer_ExpandDims_88[0][0]
#                                                                  tf_op_layer_ExpandDims_89[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_90 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Real_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_91 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Imag_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_21 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_21 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_20 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_24[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_25 (TensorF [(None, 218, 170)]   0           lambda_46[0][0]
#                                                                  lambda_47[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_21 (TensorFl [(None, 218, 170, 14 0           tf_op_layer_concat_20[0][0]
#                                                                  tf_op_layer_ExpandDims_90[0][0]
#                                                                  tf_op_layer_ExpandDims_91[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_92 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Real_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_93 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Imag_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_22 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_22 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_21 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_26 (TensorF [(None, 218, 170)]   0           lambda_48[0][0]
#                                                                  lambda_49[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 218, 170)     0           tf_op_layer_concat_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_22 (TensorFl [(None, 218, 170, 16 0           tf_op_layer_concat_21[0][0]
#                                                                  tf_op_layer_ExpandDims_92[0][0]
#                                                                  tf_op_layer_ExpandDims_93[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_94 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Real_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_95 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Imag_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_23 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_23 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_22 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_26[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_27 (TensorF [(None, 218, 170)]   0           lambda_50[0][0]
#                                                                  lambda_51[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_23 (TensorFl [(None, 218, 170, 18 0           tf_op_layer_concat_22[0][0]
#                                                                  tf_op_layer_ExpandDims_94[0][0]
#                                                                  tf_op_layer_ExpandDims_95[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_96 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Real_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_97 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Imag_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_24 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_24 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_23 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_27[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_24 (TensorFl [(None, 218, 170, 20 0           tf_op_layer_concat_23[0][0]
#                                                                  tf_op_layer_ExpandDims_96[0][0]
#                                                                  tf_op_layer_ExpandDims_97[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_98 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Real_24[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_99 (Tens [(None, 218, 170, 1) 0           tf_op_layer_Imag_24[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_25 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_25 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_25 (TensorFl [(None, 218, 170, 22 0           tf_op_layer_concat_24[0][0]
#                                                                  tf_op_layer_ExpandDims_98[0][0]
#                                                                  tf_op_layer_ExpandDims_99[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_100 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_101 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_26 (TensorFl [(None, 218, 170, 24 0           tf_op_layer_concat_25[0][0]
#                                                                  tf_op_layer_ExpandDims_100[0][0]
#                                                                  tf_op_layer_ExpandDims_101[0][0]
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 218, 170, 24 0
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 218, 170, 24) 0           tf_op_layer_concat_26[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 218, 170, 24 0
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 218, 170, 24) 0           multiply_1[0][0]
#                                                                  input_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_58 (T [(None, 218, 170, 12 0           add_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_59 (T [(None, 218, 170, 12 0           add_5[0][0]
# ...
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_246 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_60[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_61 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_61 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_57 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_64[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_65 (TensorF [(None, 218, 170)]   0           lambda_123[0][0]
#                                                                  lambda_124[0][0]
# __________________________________________________________________________________________________
# lambda_125 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# lambda_126 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_64 (TensorFl [(None, 218, 170, 16 0           tf_op_layer_concat_63[0][0]
#                                                                  tf_op_layer_ExpandDims_245[0][0]
#                                                                  tf_op_layer_ExpandDims_246[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_247 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_61[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_248 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_61[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_62 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_57[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_62 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_57[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_58 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_66 (TensorF [(None, 218, 170)]   0           lambda_125[0][0]
#                                                                  lambda_126[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_65 (TensorFl [(None, 218, 170, 18 0           tf_op_layer_concat_64[0][0]
#                                                                  tf_op_layer_ExpandDims_247[0][0]
#                                                                  tf_op_layer_ExpandDims_248[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_249 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_62[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_250 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_62[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_63 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_58[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_63 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_58[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_59 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_Complex_66[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_66 (TensorFl [(None, 218, 170, 20 0           tf_op_layer_concat_65[0][0]
#                                                                  tf_op_layer_ExpandDims_249[0][0]
#                                                                  tf_op_layer_ExpandDims_250[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_251 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_63[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_252 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_63[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_64 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_59[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_64 (TensorFlow [(None, 218, 170)]   0           tf_op_layer_FFT2D_59[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_67 (TensorFl [(None, 218, 170, 22 0           tf_op_layer_concat_66[0][0]
#                                                                  tf_op_layer_ExpandDims_251[0][0]
#                                                                  tf_op_layer_ExpandDims_252[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_253 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_64[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_254 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_64[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_68 (TensorFl [(None, 218, 170, 24 0           tf_op_layer_concat_67[0][0]
#                                                                  tf_op_layer_ExpandDims_253[0][0]
#                                                                  tf_op_layer_ExpandDims_254[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 218, 170, 24) 0           tf_op_layer_concat_68[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 218, 170, 24) 0           multiply_4[0][0]
#                                                                  input_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_142 ( [(None, 218, 170, 12 0           add_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_143 ( [(None, 218, 170, 12 0           add_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_8 (TensorFlowOp [(None, 218, 170)]   0           tf_op_layer_strided_slice_142[0][
# __________________________________________________________________________________________________
# tf_op_layer_Sum_9 (TensorFlowOp [(None, 218, 170)]   0           tf_op_layer_strided_slice_143[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_255 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Sum_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_256 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Sum_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_69 (TensorFl [(None, 218, 170, 2) 0           tf_op_layer_ExpandDims_255[0][0]
#                                                                  tf_op_layer_ExpandDims_256[0][0]
# __________________________________________________________________________________________________
# lambda_127 (Lambda)             (None, 218, 170, 2)  0           tf_op_layer_concat_69[0][0]
# ==================================================================================================
# Total params: 12,002,696
# Trainable params: 12,002,696
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 1327 steps, validate for 565 steps
#    1/1327 [..............................] - ETA: 9:12:43WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are:
#    1/1327 [..............................] - ETA: 9:47:21
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-9-c197ba5bcb19> in <module>()
#      54     print(model.summary())
#      55
# ---> 56 hist = model.fit(train_generator, epochs = epochs, steps_per_epoch = ( (nslices - crop[0] - crop[1])*len(train) ) // batch_size,              validation_data = val_generator, validation_steps = ( (nslices - crop[0] - crop[1])*len(val) ) // batch_size,                    callbacks = [ checkpoint2, checkpoint, earlyStopping ], verbose = 1)
#      57
#      58 # Save model history
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\eager\def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\eager\def_function.py in _call(self, *args, **kwds)
#     630         # Lifting succeeded, so variables are initialized and we can run the
#     631         # stateless function.
# --> 632         return self._stateless_fn(*args, **kwds)
#     633     else:
#     634       canon_args, canon_kwds = \
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    2361     with self._lock:
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#    2365   @property
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      65     else:
#      66       message = e.message
# ---> 67     six.raise_from(core._status_to_exception(e.code, message), None)
#      68   except TypeError as e:
#      69     keras_symbolic_tensors = [
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\six.py in raise_from(value, from_value)
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[8,48,112,88] and type double on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node model/max_pooling2d_9/MaxPool (defined at <ipython-input-9-c197ba5bcb19>:56) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_distributed_function_28032]
#
# Function call stack:
# distributed_function
