# %%
# Importing standard libraries
import numpy as np
import os
import glob
import sys
import importlib
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import  Adam
from tensorflow.keras.models import load_model
import pickle
import tensorflow as tf
from skimage.morphology import area_opening

# Include path to my modules
MY_UTILS_PATH = "../Modules/"
if not MY_UTILS_PATH in sys.path:
    sys.path.append(MY_UTILS_PATH)

# Import my modules
import cs_models_mc_combined as fsnet
importlib.reload(fsnet)
import cs_models_mc_combined as fsnet
from data_generator_mc_combined import DataGenerator

physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# Input parameters
H = 218
W = 170
channels = 12
batch_size = 8
epochs = 100
lr = 1e-4
patience = 10
sampling_mask_path = "../Data/poisson_sampling/R5_218x170.npy"
model_path =  "../Models/model_wwnet_ikik_mcc_r5.h5"
weights_path = "../Models/weights_wwnet_ikik_mcc_r5.h5"
model_string = "ikik"
train_path = "../../data/train_val_12_channel/Train/"
val_path = "../../data/train_val_12_channel/Val/"
cascade = "unet"
nslices = 256
crop = (15, 15)
verbose = True

# %%
train = glob.glob(train_path + "*.h5")
val = glob.glob(val_path + "*.h5")

# undersampling patterns - centered k-space - 100 pre computed patterns
var_sampling_mask = np.load(sampling_mask_path)

asc = area_opening(var_sampling_mask[0], area_threshold=10, connectivity=1, parent=None, tree_traverser=None)


if verbose:
    print(cascade)
    print("Domains: ", model_string)
    print("Model name: ", model_path)
    print("Weights path: ", weights_path)
    print("Sampling:", 1.0*var_sampling_mask.sum() / (var_sampling_mask.size*0.85)) # 85 % sampling Kz direction
    print("Train path: ", train_path)
    print("Validation path: ", val_path)


# Replicate sampling mask across number of channels
var_sampling_mask = np.repeat(var_sampling_mask[:, :, :, np.newaxis], 24, axis = -1) 

train_generator = DataGenerator(train, dim = (H, W), under_masks = var_sampling_mask,  crop = crop,\
                            batch_size = batch_size, n_channels = channels * 2, nslices = nslices, shuffle=True, asc = asc)

val_generator = DataGenerator(val, dim = (H, W), under_masks = var_sampling_mask,  crop = crop,\
                            batch_size = batch_size, n_channels = channels * 2, nslices= nslices, shuffle=False, asc = asc)



# Callbacks
earlyStopping = EarlyStopping(monitor='val_loss',
                                           patience=patience, 
                                           verbose=0, mode='min')

checkpoint = ModelCheckpoint(weights_path, mode = 'min', \
                             monitor='val_loss',verbose=0,\
                             save_best_only=True, save_weights_only = True)

checkpoint2 = ModelCheckpoint(model_path, monitor='val_loss', verbose=0, save_best_only=False,\
                save_weights_only=False, mode='min')

Hpad = (8 - (H%8)) // 2
Wpad = (8 - (W%8)) // 2
if os.path.isfile(model_path):
    model = load_model(model_path)
elif  cascade == 'unet':
    model = fsnet.deep_cascade_unet(depth_str = model_string, H = H, W = W, Hpad = Hpad, Wpad = Wpad, channels = channels) 
elif cascade == 'flat':
    model = fsnet.deep_cascade_flat_unrolled(depth_str = model_string, H = H,W = W,depth = 6, kshape = (3,3), nf = 64,channels = channels)
else:
   pass

if not os.path.isfile(model_path):
    opt = Adam(learning_rate = lr)
    model.compile(loss = 'mse',optimizer=opt)

if verbose:
    print(model.summary())

hist = model.fit(train_generator, epochs = epochs, steps_per_epoch = ( (nslices - crop[0] - crop[1])*len(train) ) // batch_size, \
             validation_data = val_generator, validation_steps = ( (nslices - crop[0] - crop[1])*len(val) ) // batch_size, \
                   callbacks = [ checkpoint2, checkpoint, earlyStopping ], verbose = 1)

# Save model history
with open(model_path[:-2] + "history", 'wb') as file_pi:
    pickle.dump(hist.history, file_pi)
# Out:
# unet
# Domains:  ikik
# Model name:  ../Models/model_wwnet_ikik_mcc_r5.h5
# Weights path:  ../Models/weights_wwnet_ikik_mcc_r5.h5
# Sampling: 0.2008279102250722
# Train path:  ../../data/train_val_12_channel/Train/
# Validation path:  ../../data/train_val_12_channel/Val/
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_19 (InputLayer)           [(None, 218, 170, 2) 0
# __________________________________________________________________________________________________
# lambda_253 (Lambda)             (None, 218, 170, 2)  0           input_19[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 224, 176, 2)  0           lambda_253[0][0]
# __________________________________________________________________________________________________
# conv2d_242 (Conv2D)             (None, 224, 176, 48) 912         zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 224, 176, 48) 20784       conv2d_242[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 224, 176, 48) 20784       conv2d_243[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_33 (MaxPooling2D) (None, 112, 88, 48)  0           conv2d_244[0][0]
# __________________________________________________________________________________________________
# conv2d_245 (Conv2D)             (None, 112, 88, 64)  27712       max_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_246 (Conv2D)             (None, 112, 88, 64)  36928       conv2d_245[0][0]
# __________________________________________________________________________________________________
# conv2d_247 (Conv2D)             (None, 112, 88, 64)  36928       conv2d_246[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_34 (MaxPooling2D) (None, 56, 44, 64)   0           conv2d_247[0][0]
# __________________________________________________________________________________________________
# conv2d_248 (Conv2D)             (None, 56, 44, 128)  73856       max_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_249 (Conv2D)             (None, 56, 44, 128)  147584      conv2d_248[0][0]
# __________________________________________________________________________________________________
# conv2d_250 (Conv2D)             (None, 56, 44, 128)  147584      conv2d_249[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_35 (MaxPooling2D) (None, 28, 22, 128)  0           conv2d_250[0][0]
# __________________________________________________________________________________________________
# conv2d_251 (Conv2D)             (None, 28, 22, 256)  295168      max_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_252 (Conv2D)             (None, 28, 22, 256)  590080      conv2d_251[0][0]
# __________________________________________________________________________________________________
# conv2d_253 (Conv2D)             (None, 28, 22, 256)  590080      conv2d_252[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_33 (UpSampling2D) (None, 56, 44, 256)  0           conv2d_253[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 56, 44, 384)  0           up_sampling2d_33[0][0]
#                                                                  conv2d_250[0][0]
# __________________________________________________________________________________________________
# conv2d_254 (Conv2D)             (None, 56, 44, 128)  442496      concatenate_33[0][0]
# __________________________________________________________________________________________________
# conv2d_255 (Conv2D)             (None, 56, 44, 128)  147584      conv2d_254[0][0]
# __________________________________________________________________________________________________
# conv2d_256 (Conv2D)             (None, 56, 44, 128)  147584      conv2d_255[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_34 (UpSampling2D) (None, 112, 88, 128) 0           conv2d_256[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 112, 88, 192) 0           up_sampling2d_34[0][0]
#                                                                  conv2d_247[0][0]
# __________________________________________________________________________________________________
# conv2d_257 (Conv2D)             (None, 112, 88, 64)  110656      concatenate_34[0][0]
# __________________________________________________________________________________________________
# conv2d_258 (Conv2D)             (None, 112, 88, 64)  36928       conv2d_257[0][0]
# __________________________________________________________________________________________________
# conv2d_259 (Conv2D)             (None, 112, 88, 64)  36928       conv2d_258[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_35 (UpSampling2D) (None, 224, 176, 64) 0           conv2d_259[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 224, 176, 112 0           up_sampling2d_35[0][0]
#                                                                  conv2d_244[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 224, 176, 48) 48432       concatenate_35[0][0]
# __________________________________________________________________________________________________
# conv2d_261 (Conv2D)             (None, 224, 176, 48) 20784       conv2d_260[0][0]
# __________________________________________________________________________________________________
# conv2d_262 (Conv2D)             (None, 224, 176, 48) 20784       conv2d_261[0][0]
# __________________________________________________________________________________________________
# conv2d_263 (Conv2D)             (None, 224, 176, 2)  98          conv2d_262[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 224, 176, 2)  0           conv2d_263[0][0]
#                                                                  zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# cropping2d_11 (Cropping2D)      (None, 218, 170, 2)  0           add_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_278 ( [(None, 218, 170)]   0           cropping2d_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_279 ( [(None, 218, 170)]   0           cropping2d_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_131 (Tensor [(None, 218, 170)]   0           tf_op_layer_strided_slice_278[0][
#                                                                  tf_op_layer_strided_slice_279[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_507 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Complex_131[0][0]
# __________________________________________________________________________________________________
# input_21 (InputLayer)           [(None, 218, 170, 12 0
# __________________________________________________________________________________________________
# tf_op_layer_Mul_10 (TensorFlowO [(None, 218, 170, 12 0           tf_op_layer_ExpandDims_507[0][0]
#                                                                  input_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_130 (TensorFlo [(None, 218, 170, 12 0           tf_op_layer_Mul_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_130 (TensorFlo [(None, 218, 170, 12 0           tf_op_layer_Mul_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_280 ( [(None, 218, 170)]   0           tf_op_layer_Real_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_281 ( [(None, 218, 170)]   0           tf_op_layer_Imag_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_282 ( [(None, 218, 170)]   0           tf_op_layer_Real_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_283 ( [(None, 218, 170)]   0           tf_op_layer_Imag_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_284 ( [(None, 218, 170)]   0           tf_op_layer_Real_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_285 ( [(None, 218, 170)]   0           tf_op_layer_Imag_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_286 ( [(None, 218, 170)]   0           tf_op_layer_Real_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_287 ( [(None, 218, 170)]   0           tf_op_layer_Imag_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_288 ( [(None, 218, 170)]   0           tf_op_layer_Real_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_289 ( [(None, 218, 170)]   0           tf_op_layer_Imag_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_290 ( [(None, 218, 170)]   0           tf_op_layer_Real_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_291 ( [(None, 218, 170)]   0           tf_op_layer_Imag_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_292 ( [(None, 218, 170)]   0           tf_op_layer_Real_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_293 ( [(None, 218, 170)]   0           tf_op_layer_Imag_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_294 ( [(None, 218, 170)]   0           tf_op_layer_Real_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_295 ( [(None, 218, 170)]   0           tf_op_layer_Imag_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_296 ( [(None, 218, 170)]   0           tf_op_layer_Real_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_297 ( [(None, 218, 170)]   0           tf_op_layer_Imag_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_298 ( [(None, 218, 170)]   0           tf_op_layer_Real_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_299 ( [(None, 218, 170)]   0           tf_op_layer_Imag_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_300 ( [(None, 218, 170)]   0           tf_op_layer_Real_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_301 ( [(None, 218, 170)]   0           tf_op_layer_Imag_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_302 ( [(None, 218, 170)]   0           tf_op_layer_Real_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_303 ( [(None, 218, 170)]   0           tf_op_layer_Imag_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_508 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_280[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_509 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_281[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_510 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_282[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_511 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_283[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_512 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_284[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_513 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_285[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_514 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_286[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_515 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_287[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_516 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_288[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_517 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_289[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_518 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_290[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_519 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_291[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_520 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_292[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_521 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_293[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_522 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_294[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_523 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_295[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_524 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_296[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_525 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_297[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_526 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_298[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_527 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_299[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_528 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_300[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_529 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_301[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_530 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_302[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_531 (Ten [(None, 218, 170, 1) 0           tf_op_layer_strided_slice_303[0][
# __________________________________________________________________________________________________
# tf_op_layer_concat_138 (TensorF [(None, 218, 170, 24 0           tf_op_layer_ExpandDims_508[0][0]
#                                                                  tf_op_layer_ExpandDims_509[0][0]
#                                                                  tf_op_layer_ExpandDims_510[0][0]
#                                                                  tf_op_layer_ExpandDims_511[0][0]
#                                                                  tf_op_layer_ExpandDims_512[0][0]
#                                                                  tf_op_layer_ExpandDims_513[0][0]
#                                                                  tf_op_layer_ExpandDims_514[0][0]
#                                                                  tf_op_layer_ExpandDims_515[0][0]
#                                                                  tf_op_layer_ExpandDims_516[0][0]
#                                                                  tf_op_layer_ExpandDims_517[0][0]
#                                                                  tf_op_layer_ExpandDims_518[0][0]
#                                                                  tf_op_layer_ExpandDims_519[0][0]
#                                                                  tf_op_layer_ExpandDims_520[0][0]
#                                                                  tf_op_layer_ExpandDims_521[0][0]
#                                                                  tf_op_layer_ExpandDims_522[0][0]
#                                                                  tf_op_layer_ExpandDims_523[0][0]
#                                                                  tf_op_layer_ExpandDims_524[0][0]
#                                                                  tf_op_layer_ExpandDims_525[0][0]
#                                                                  tf_op_layer_ExpandDims_526[0][0]
#                                                                  tf_op_layer_ExpandDims_527[0][0]
#                                                                  tf_op_layer_ExpandDims_528[0][0]
#                                                                  tf_op_layer_ExpandDims_529[0][0]
#                                                                  tf_op_layer_ExpandDims_530[0][0]
#                                                                  tf_op_layer_ExpandDims_531[0][0]
# __________________________________________________________________________________________________
# lambda_254 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# lambda_255 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_132 (Tensor [(None, 218, 170)]   0           lambda_254[0][0]
#                                                                  lambda_255[0][0]
# __________________________________________________________________________________________________
# lambda_256 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# lambda_257 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_120 (TensorFl [(None, 218, 170)]   0           tf_op_layer_Complex_132[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_133 (Tensor [(None, 218, 170)]   0           lambda_256[0][0]
#                                                                  lambda_257[0][0]
# __________________________________________________________________________________________________
# lambda_258 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# lambda_259 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_131 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_120[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_131 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_120[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_121 (TensorFl [(None, 218, 170)]   0           tf_op_layer_Complex_133[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_134 (Tensor [(None, 218, 170)]   0           lambda_258[0][0]
#                                                                  lambda_259[0][0]
# __________________________________________________________________________________________________
# lambda_260 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# lambda_261 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_532 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_131[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_533 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_131[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_132 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_121[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_132 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_121[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_122 (TensorFl [(None, 218, 170)]   0           tf_op_layer_Complex_134[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_135 (Tensor [(None, 218, 170)]   0           lambda_260[0][0]
#                                                                  lambda_261[0][0]
# __________________________________________________________________________________________________
# lambda_262 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# lambda_263 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_139 (TensorF [(None, 218, 170, 2) 0           tf_op_layer_ExpandDims_532[0][0]
#                                                                  tf_op_layer_ExpandDims_533[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_534 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_132[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_535 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_132[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_133 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_122[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_133 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_122[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_123 (TensorFl [(None, 218, 170)]   0           tf_op_layer_Complex_135[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_136 (Tensor [(None, 218, 170)]   0           lambda_262[0][0]
#                                                                  lambda_263[0][0]
# __________________________________________________________________________________________________
# lambda_264 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# lambda_265 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_140 (TensorF [(None, 218, 170, 4) 0           tf_op_layer_concat_139[0][0]
#                                                                  tf_op_layer_ExpandDims_534[0][0]
#                                                                  tf_op_layer_ExpandDims_535[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_536 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_133[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_537 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_133[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_134 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_123[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_134 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_123[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_124 (TensorFl [(None, 218, 170)]   0           tf_op_layer_Complex_136[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_137 (Tensor [(None, 218, 170)]   0           lambda_264[0][0]
#                                                                  lambda_265[0][0]
# __________________________________________________________________________________________________
# lambda_266 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# lambda_267 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_141 (TensorF [(None, 218, 170, 6) 0           tf_op_layer_concat_140[0][0]
#                                                                  tf_op_layer_ExpandDims_536[0][0]
#                                                                  tf_op_layer_ExpandDims_537[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_538 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_134[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_539 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_134[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_135 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_124[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_135 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_124[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_125 (TensorFl [(None, 218, 170)]   0           tf_op_layer_Complex_137[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_138 (Tensor [(None, 218, 170)]   0           lambda_266[0][0]
#                                                                  lambda_267[0][0]
# __________________________________________________________________________________________________
# lambda_268 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# lambda_269 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_142 (TensorF [(None, 218, 170, 8) 0           tf_op_layer_concat_141[0][0]
#                                                                  tf_op_layer_ExpandDims_538[0][0]
#                                                                  tf_op_layer_ExpandDims_539[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_540 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_135[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_541 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_135[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_136 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_125[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_136 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_125[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_126 (TensorFl [(None, 218, 170)]   0           tf_op_layer_Complex_138[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_139 (Tensor [(None, 218, 170)]   0           lambda_268[0][0]
#                                                                  lambda_269[0][0]
# __________________________________________________________________________________________________
# lambda_270 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# lambda_271 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_143 (TensorF [(None, 218, 170, 10 0           tf_op_layer_concat_142[0][0]
#                                                                  tf_op_layer_ExpandDims_540[0][0]
#                                                                  tf_op_layer_ExpandDims_541[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_542 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_136[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_543 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_136[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_137 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_126[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_137 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_126[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_127 (TensorFl [(None, 218, 170)]   0           tf_op_layer_Complex_139[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_140 (Tensor [(None, 218, 170)]   0           lambda_270[0][0]
#                                                                  lambda_271[0][0]
# __________________________________________________________________________________________________
# lambda_272 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# lambda_273 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_144 (TensorF [(None, 218, 170, 12 0           tf_op_layer_concat_143[0][0]
#                                                                  tf_op_layer_ExpandDims_542[0][0]
#                                                                  tf_op_layer_ExpandDims_543[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_544 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_137[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_545 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_137[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_138 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_127[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_138 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_127[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_128 (TensorFl [(None, 218, 170)]   0           tf_op_layer_Complex_140[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_141 (Tensor [(None, 218, 170)]   0           lambda_272[0][0]
#                                                                  lambda_273[0][0]
# __________________________________________________________________________________________________
# lambda_274 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# lambda_275 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_145 (TensorF [(None, 218, 170, 14 0           tf_op_layer_concat_144[0][0]
#                                                                  tf_op_layer_ExpandDims_544[0][0]
#                                                                  tf_op_layer_ExpandDims_545[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_546 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_138[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_547 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_138[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_139 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_128[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_139 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_128[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_129 (TensorFl [(None, 218, 170)]   0           tf_op_layer_Complex_141[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_142 (Tensor [(None, 218, 170)]   0           lambda_274[0][0]
#                                                                  lambda_275[0][0]
# __________________________________________________________________________________________________
# lambda_276 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# lambda_277 (Lambda)             (None, 218, 170)     0           tf_op_layer_concat_138[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_146 (TensorF [(None, 218, 170, 16 0           tf_op_layer_concat_145[0][0]
#                                                                  tf_op_layer_ExpandDims_546[0][0]
#                                                                  tf_op_layer_ExpandDims_547[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_548 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_139[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_549 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_139[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_140 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_129[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_140 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_129[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_130 (TensorFl [(None, 218, 170)]   0           tf_op_layer_Complex_142[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_143 (Tensor [(None, 218, 170)]   0           lambda_276[0][0]
#                                                                  lambda_277[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_147 (TensorF [(None, 218, 170, 18 0           tf_op_layer_concat_146[0][0]
#                                                                  tf_op_layer_ExpandDims_548[0][0]
#                                                                  tf_op_layer_ExpandDims_549[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_550 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_140[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_551 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_140[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_141 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_141 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_130[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_131 (TensorFl [(None, 218, 170)]   0           tf_op_layer_Complex_143[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_148 (TensorF [(None, 218, 170, 20 0           tf_op_layer_concat_147[0][0]
#                                                                  tf_op_layer_ExpandDims_550[0][0]
#                                                                  tf_op_layer_ExpandDims_551[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_552 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_141[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_553 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_141[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_142 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_131[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_142 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_131[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_149 (TensorF [(None, 218, 170, 22 0           tf_op_layer_concat_148[0][0]
#                                                                  tf_op_layer_ExpandDims_552[0][0]
#                                                                  tf_op_layer_ExpandDims_553[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_554 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_142[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_555 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_142[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_150 (TensorF [(None, 218, 170, 24 0           tf_op_layer_concat_149[0][0]
#                                                                  tf_op_layer_ExpandDims_554[0][0]
#                                                                  tf_op_layer_ExpandDims_555[0][0]
# __________________________________________________________________________________________________
# input_20 (InputLayer)           [(None, 218, 170, 24 0
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 218, 170, 24) 0           tf_op_layer_concat_150[0][0]
#                                                                  input_20[0][0]
# __________________________________________________________________________________________________
# input_22 (InputLayer)           [(None, 218, 170, 24 0
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 218, 170, 24) 0           multiply_10[0][0]
#                                                                  input_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_304 ( [(None, 218, 170, 12 0           add_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_305 ( [(None, 218, 170, 12 0           add_22[0][0]
# ...
# tf_op_layer_concat_188 (TensorF [(None, 218, 170, 16 0           tf_op_layer_concat_187[0][0]
#                                                                  tf_op_layer_ExpandDims_699[0][0]
#                                                                  tf_op_layer_ExpandDims_700[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_701 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_178[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_702 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_178[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_179 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_165[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_179 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_165[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_166 (TensorFl [(None, 218, 170)]   0           tf_op_layer_Complex_181[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Complex_182 (Tensor [(None, 218, 170)]   0           lambda_351[0][0]
#                                                                  lambda_352[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_189 (TensorF [(None, 218, 170, 18 0           tf_op_layer_concat_188[0][0]
#                                                                  tf_op_layer_ExpandDims_701[0][0]
#                                                                  tf_op_layer_ExpandDims_702[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_703 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_179[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_704 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_179[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_180 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_166[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_180 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_166[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_FFT2D_167 (TensorFl [(None, 218, 170)]   0           tf_op_layer_Complex_182[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_190 (TensorF [(None, 218, 170, 20 0           tf_op_layer_concat_189[0][0]
#                                                                  tf_op_layer_ExpandDims_703[0][0]
#                                                                  tf_op_layer_ExpandDims_704[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_705 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_180[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_706 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_180[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Real_181 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_167[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Imag_181 (TensorFlo [(None, 218, 170)]   0           tf_op_layer_FFT2D_167[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_191 (TensorF [(None, 218, 170, 22 0           tf_op_layer_concat_190[0][0]
#                                                                  tf_op_layer_ExpandDims_705[0][0]
#                                                                  tf_op_layer_ExpandDims_706[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_707 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Real_181[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_708 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Imag_181[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_192 (TensorF [(None, 218, 170, 24 0           tf_op_layer_concat_191[0][0]
#                                                                  tf_op_layer_ExpandDims_707[0][0]
#                                                                  tf_op_layer_ExpandDims_708[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 218, 170, 24) 0           tf_op_layer_concat_192[0][0]
#                                                                  input_20[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 218, 170, 24) 0           multiply_13[0][0]
#                                                                  input_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_388 ( [(None, 218, 170, 12 0           add_28[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_389 ( [(None, 218, 170, 12 0           add_28[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_22 (TensorFlowO [(None, 218, 170)]   0           tf_op_layer_strided_slice_388[0][
# __________________________________________________________________________________________________
# tf_op_layer_Sum_23 (TensorFlowO [(None, 218, 170)]   0           tf_op_layer_strided_slice_389[0][
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_709 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Sum_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_710 (Ten [(None, 218, 170, 1) 0           tf_op_layer_Sum_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_193 (TensorF [(None, 218, 170, 2) 0           tf_op_layer_ExpandDims_709[0][0]
#                                                                  tf_op_layer_ExpandDims_710[0][0]
# __________________________________________________________________________________________________
# lambda_353 (Lambda)             (None, 218, 170, 2)  0           tf_op_layer_concat_193[0][0]
# ==================================================================================================
# Total params: 12,002,696
# Trainable params: 12,002,696
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# ../Modules\data_generator_mc_combined.py:82: RuntimeWarning: invalid value encountered in true_divide
#   S = x_hat / norm_factor[:, :, :, np.newaxis]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Epoch 1/100
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 0 batches). You may need to use the repeat() function when building your dataset.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_epoch(self, epoch, mode)
#     766     try:
# --> 767       yield epoch_logs
#     768     finally:
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     186   # End of an epoch.
# --> 187   aggregator.finalize()
#     188   return aggregator.results
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py in finalize(self)
#     143     if not self.results:
# --> 144       raise ValueError('Empty training data.')
#     145     self.results[0] /= (self.num_samples or self.steps)
#
# ValueError: Empty training data.
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\callbacks.py in _save_model(self, epoch, logs)
#    1039           else:
# -> 1040             self.model.save(filepath, overwrite=True)
#    1041
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\engine\network.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options)
#    1007     save.save_model(self, filepath, overwrite, include_optimizer, save_format,
# -> 1008                     signatures, options)
#    1009
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\saving\save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options)
#     111     hdf5_format.save_model_to_hdf5(
# --> 112         model, filepath, overwrite, include_optimizer)
#     113   else:
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\saving\hdf5_format.py in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#      91
# ---> 92     f = h5py.File(filepath, mode='w')
#      93     opened_new_file = True
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     311                 fapl = make_fapl(driver, libver, **kwds)
# --> 312                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     313
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\h5py\_hl\files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     147     elif mode == 'w':
# --> 148         fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     149     elif mode == 'a':
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5f.pyx in h5py.h5f.create()
#
# OSError: Unable to create file (unable to open file: name = '../Models/model_wwnet_ikik_mcc_r5.h5', errno = 2, error message = 'No such file or directory', flags = 13, o_flags = 302)
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-4dca08f7f54c> in <module>()
#      54     print(model.summary())
#      55
# ---> 56 hist = model.fit(train_generator, epochs = epochs, steps_per_epoch = ( (nslices - crop[0] - crop[1])*len(train) ) // batch_size,              validation_data = val_generator, validation_steps = ( (nslices - crop[0] - crop[1])*len(val) ) // batch_size,                    callbacks = [ checkpoint2, checkpoint, earlyStopping ], verbose = 1)
#      57
#      58 # Save model history
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     395                       total_epochs=1)
#     396                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
# --> 397                                  prefix='val_')
#     398
#     399     return model.history
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_epoch(self, epoch, mode)
#     769       if mode == ModeKeys.TRAIN:
#     770         # Epochs only apply to `fit`.
# --> 771         self.callbacks.on_epoch_end(epoch, epoch_logs)
#     772       self.progbar.on_epoch_end(epoch, epoch_logs)
#     773
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     300     logs = logs or {}
#     301     for callback in self.callbacks:
# --> 302       callback.on_epoch_end(epoch, logs)
#     303
#     304   def on_train_batch_begin(self, batch, logs=None):
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     990           self._save_model(epoch=epoch, logs=logs)
#     991       else:
# --> 992         self._save_model(epoch=epoch, logs=logs)
#     993     if self.model._in_multi_worker_mode():
#     994       # For multi-worker training, back up the weights and current training
#
# C:\Users\anam_\anaconda3\envs\tf2gpu\lib\site-packages\tensorflow_core\python\keras\callbacks.py in _save_model(self, epoch, logs)
#    1043       except IOError as e:
#    1044         # `e.errno` appears to be `None` so checking the content of `e.message`.
# -> 1045         if 'is a directory' in e.message:
#    1046           raise IOError('Please specify a non-directory filepath for '
#    1047                         'ModelCheckpoint. Filepath used is an existing '
#
# AttributeError: 'OSError' object has no attribute 'message'
